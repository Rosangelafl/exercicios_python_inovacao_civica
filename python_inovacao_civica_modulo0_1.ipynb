# %% [markdown]
# ### Aula ao vivo, resolvendo o desafio da semana 0

# %%
num1 = int(input('Digite o 1º número: '))
num2 = int(input('Digite o 2º número: '))
num3 = int(input('Digite o 3º número: '))

soma = num1 + num2 + num3 

print(f'Entrada: {num1}, {num2}, {num3}')
print(f'Processamento: {num1} + {num2} + {num3}')
print(f'Saída:{soma}')
# Out:
# Digite o 1º número: 10
# Digite o 2º número: 15
# Digite o 3º número: 30
# Entrada: 10, 15, 30
# Processamento: 10 + 15 + 30
# Saída:55

# %% [markdown]
# ### Módulo 2 https://github.com/escola-de-dados/python-inovacao-civica/tree/main/modulo_1

# %% [markdown]
# ## Aula 3

# %%
sg_partido = ['PSOL']

# %%
sg_partido_letra_p = []
sg_partido_letra_nao_definida = []

# %%
# os itens de uma string também podem ser identificados através do índice
if sg_partido[0][0] == 'P': # nessa linha estamos identificando o 1º item da lista e o 1º letra da palavra
    sg_partido_letra_p.append(sg_partido[0])    
else:
    sg_partido_letra_nao_definida.append(sg_partido[0])

# %%
print(f'Os partidos cujas as siglas iniciam com a letra P são: {sg_partido_letra_p}.')
print(f'Os partidos cujas as siglas não iniciam com a letra P são: {sg_partido_letra_nao_definida}.')
# Out:
# Os partidos cujas as siglas iniciam com a letra P são: ['PSOL'].
# Os partidos cujas as siglas não iniciam com a letra P são: [].

# %%
candidatura = {'DT_GERACAO': '22/05/2021',
  'HH_GERACAO': '12:18:46',
  'ANO_ELEICAO': 2020,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 426,
  'DS_ELEICAO': 'Eleições Municipais 2020',
  'DT_ELEICAO': '15/11/2020',
  'TP_ABRANGENCIA': 'MUNICIPAL',
  'SG_UF': 'PE',
  'SG_UE': 25216,
  'NM_UE': 'PETROLINA',
  'CD_CARGO': 13,
  'DS_CARGO': 'VEREADOR',
  'SQ_CANDIDATO': 170000824939,
  'NR_CANDIDATO': 25100,
  'NM_CANDIDATO': 'DANIELA TAMARA SANTOS SILVA',
  'NM_URNA_CANDIDATO': 'DANI PLUS',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 4670632493,
  'NM_EMAIL': 'DANIELE.SEDESDH@GMAIL.COM',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 25,
  'SG_PARTIDO': 'DEM',
  'NM_PARTIDO': 'DEMOCRATAS',
  'SQ_COLIGACAO': 170000086526,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'DEM',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'BA',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'JUAZEIRO',
  'DT_NASCIMENTO': '01/05/1981',
  'NR_IDADE_DATA_POSSE': 39,
  'NR_TITULO_ELEITORAL_CANDIDATO': 53652250884,
  'CD_GENERO': 4,
  'DS_GENERO': 'FEMININO',
  'CD_GRAU_INSTRUCAO': 7,
  'DS_GRAU_INSTRUCAO': 'SUPERIOR INCOMPLETO',
  'CD_ESTADO_CIVIL': 1,
  'DS_ESTADO_CIVIL': 'SOLTEIRO(A)',
  'CD_COR_RACA': 2,
  'DS_COR_RACA': 'PRETA',
  'CD_OCUPACAO': 931,
  'DS_OCUPACAO': 'ESTUDANTE, BOLSISTA, ESTAGIÁRIO E ASSEMELHADOS',
  'VR_DESPESA_MAX_CAMPANHA': 131218.52,
  'CD_SIT_TOT_TURNO': 5,
  'DS_SIT_TOT_TURNO': 'SUPLENTE',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'N',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6002695420206170083,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM'}

# %%
#estabelecendo faixas etárias co listas vazias
anos_18_24 = []
anos_25_34 = []
anos_35_44 = []
anos_45_54 = []
anos_55_64 = []
anos_acima_64 = []

# %%
if candidatura['NR_IDADE_DATA_POSSE'] >= 18 and candidatura['NR_IDADE_DATA_POSSE'] <= 24:
    anos_18_24.append(candidatura['NM_CANDIDATO'])
elif candidatura['NR_IDADE_DATA_POSSE'] >= 25 and candidatura['NR_IDADE_DATA_POSSE'] <= 34:
    anos_25_34.append(candidatura['NM_CANDIDATO'])
elif candidatura['NR_IDADE_DATA_POSSE'] >= 35 and candidatura['NR_IDADE_DATA_POSSE'] <= 44:
    anos_35_44.append(candidatura['NM_CANDIDATO'])
elif candidatura['NR_IDADE_DATA_POSSE'] >= 45 and candidatura['NR_IDADE_DATA_POSSE'] <= 54:
    anos_45_54.append(candidatura['NM_CANDIDATO'])
elif candidatura['NR_IDADE_DATA_POSSE'] >= 55 and candidatura['NR_IDADE_DATA_POSSE'] <= 64:
    anos_55_64.append(candidatura['NM_CANDIDATO'])
else:
    anos_acima_64.append(candidatura['NM_CANDIDATO'])

# %%
print(f'Candidaturas por faixa etária:')
print(f'18-24 anos: {anos_18_24}')
print(f'25-34 anos: {anos_25_34}')
print(f'35-44 anos: {anos_35_44}')
print(f'45-54 anos: {anos_45_54}')
print(f'55-64 anos: {anos_55_64}')
print(f'acima 64 anos: {anos_acima_64}')
# Out:
# Candidaturas por faixa etária:
# 18-24 anos: []
# 25-34 anos: []
# 35-44 anos: ['DANIELA TAMARA SANTOS SILVA']
# 45-54 anos: []
# 55-64 anos: []
# acima 64 anos: []

# %% [markdown]
# Aula 5: Estrutura de controle: interação
# Repetiremos o exercício da aula anterior, dessa vez complementando o código usando a estrutura de controle do tipo interação (for). Desse modo poderemos classificar vários elementos de uma lista ou dicionário.
#
# Nesse primeiro exemplo, classificaremos os itens da lista em um dos seguintes grupos:
#
# Partidos que suas siglas iniciem com a letra P
# Partidos que iniciem com outra letra

# %% [markdown]
# #### Aula 4 - estruturas de controles do tipo iteração e conhecerá a função range

# %% [markdown]
# ##### Estrutura do range

# %%
#range(início, fim, passo)
list(range(9))
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
list(range(4,9,2))
# Out:
# [4, 6, 8]

# %% [markdown]
# ![for and else.jpg](data:image/jpeg;base64,...)

# %%
sg_partido = ['DEM', 'DC', 'PTB', 'REPUBLICANOS', 'PSL', 'PC do B', 'PTC',
       'CIDADANIA', 'PSOL', 'MDB', 'PT', 'PSB', 'AVANTE', 'PATRIOTA',
       'PSD', 'PDT', 'PRTB', 'PL', 'REDE', 'PODE', 'PSDB', 'PMN', 'PP',
       'PSC', 'SOLIDARIEDADE', 'PROS', 'PV', 'PCB', 'PMB', 'UP', 'NOVO',
       'PCO', 'PSTU']

# %%
sg_partido_letra_p = []
sg_partido_letra_nao_definida = []

# %%
for sigla in sg_partido:

    if sigla[0] == 'P':
        sg_partido_letra_p.append(sigla)    
    else:
        sg_partido_letra_nao_definida.append(sigla)
else:
    print('Atividade concluída')
# Out:
# Atividade concluída

# %%
print(f'Os partidos cujas as siglas iniciam com a letra P são: {sg_partido_letra_p}.')
# Out:
# Os partidos cujas as siglas iniciam com a letra P são: ['PTB', 'PSL', 'PC do B', 'PTC', 'PSOL', 'PT', 'PSB', 'PATRIOTA', 'PSD', 'PDT', 'PRTB', 'PL', 'PODE', 'PSDB', 'PMN', 'PP', 'PSC', 'PROS', 'PV', 'PCB', 'PMB', 'PCO', 'PSTU'].

# %%
print(f'Os partidos cujas as siglas não iniciam com a letra P são: {sg_partido_letra_nao_definida}.')
# Out:
# Os partidos cujas as siglas não iniciam com a letra P são: ['DEM', 'DC', 'REPUBLICANOS', 'CIDADANIA', 'MDB', 'AVANTE', 'REDE', 'SOLIDARIEDADE', 'UP', 'NOVO'].

# %% [markdown]
# Nesse segundo exemplo, classificaremos os itens do dicionário em um dos seguintes grupos:
#
# 18-24 anos
#
# 25-34 anos
#
# 35-44 anos
#
# 45-54 anos
#
# 55-64 anos
#
# acima 64 anos

# %%
candidaturas = [{'DT_GERACAO': '22/05/2021',
  'HH_GERACAO': '12:18:46',
  'ANO_ELEICAO': 2020,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 426,
  'DS_ELEICAO': 'Eleições Municipais 2020',
  'DT_ELEICAO': '15/11/2020',
  'TP_ABRANGENCIA': 'MUNICIPAL',
  'SG_UF': 'PE',
  'SG_UE': 25216,
  'NM_UE': 'PETROLINA',
  'CD_CARGO': 13,
  'DS_CARGO': 'VEREADOR',
  'SQ_CANDIDATO': 170000824939,
  'NR_CANDIDATO': 25100,
  'NM_CANDIDATO': 'DANIELA TAMARA SANTOS SILVA',
  'NM_URNA_CANDIDATO': 'DANI PLUS',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 4670632493,
  'NM_EMAIL': 'DANIELE.SEDESDH@GMAIL.COM',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 25,
  'SG_PARTIDO': 'DEM',
  'NM_PARTIDO': 'DEMOCRATAS',
  'SQ_COLIGACAO': 170000086526,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'DEM',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'BA',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'JUAZEIRO',
  'DT_NASCIMENTO': '01/05/1981',
  'NR_IDADE_DATA_POSSE': 39,
  'NR_TITULO_ELEITORAL_CANDIDATO': 53652250884,
  'CD_GENERO': 4,
  'DS_GENERO': 'FEMININO',
  'CD_GRAU_INSTRUCAO': 7,
  'DS_GRAU_INSTRUCAO': 'SUPERIOR INCOMPLETO',
  'CD_ESTADO_CIVIL': 1,
  'DS_ESTADO_CIVIL': 'SOLTEIRO(A)',
  'CD_COR_RACA': 2,
  'DS_COR_RACA': 'PRETA',
  'CD_OCUPACAO': 931,
  'DS_OCUPACAO': 'ESTUDANTE, BOLSISTA, ESTAGIÁRIO E ASSEMELHADOS',
  'VR_DESPESA_MAX_CAMPANHA': 131218.52,
  'CD_SIT_TOT_TURNO': 5,
  'DS_SIT_TOT_TURNO': 'SUPLENTE',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'N',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6002695420206170083,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM'},
 {'DT_GERACAO': '22/05/2021',
  'HH_GERACAO': '12:18:46',
  'ANO_ELEICAO': 2020,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 426,
  'DS_ELEICAO': 'Eleições Municipais 2020',
  'DT_ELEICAO': '15/11/2020',
  'TP_ABRANGENCIA': 'MUNICIPAL',
  'SG_UF': 'PE',
  'SG_UE': 26310,
  'NM_UE': 'ABREU E LIMA',
  'CD_CARGO': 13,
  'DS_CARGO': 'VEREADOR',
  'SQ_CANDIDATO': 170001246990,
  'NR_CANDIDATO': 27777,
  'NM_CANDIDATO': 'SEVERINO ALVES DA SILVA FILHO',
  'NM_URNA_CANDIDATO': 'SILVIO',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 17986117400,
  'NM_EMAIL': 'FENAMUDANCA01@GMAIL.COM',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 27,
  'SG_PARTIDO': 'DC',
  'NM_PARTIDO': 'DEMOCRACIA CRISTÃ',
  'SQ_COLIGACAO': 170000154616,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'DC',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'RJ',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'RIO DE JANEIRO',
  'DT_NASCIMENTO': '25/09/1956',
  'NR_IDADE_DATA_POSSE': 64,
  'NR_TITULO_ELEITORAL_CANDIDATO': 11232980868,
  'CD_GENERO': 2,
  'DS_GENERO': 'MASCULINO',
  'CD_GRAU_INSTRUCAO': 3,
  'DS_GRAU_INSTRUCAO': 'ENSINO FUNDAMENTAL INCOMPLETO',
  'CD_ESTADO_CIVIL': 5,
  'DS_ESTADO_CIVIL': 'VIÚVO(A)',
  'CD_COR_RACA': 3,
  'DS_COR_RACA': 'PARDA',
  'CD_OCUPACAO': 246,
  'DS_OCUPACAO': 'TÉCNICO DE OBRAS CIVIS, ESTRADAS, SANEAMENTO E ASSEMELHADOS',
  'VR_DESPESA_MAX_CAMPANHA': 28533.15,
  'CD_SIT_TOT_TURNO': 4,
  'DS_SIT_TOT_TURNO': 'NÃO ELEITO',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6003620620206170119,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM'},
 {'DT_GERACAO': '22/05/2021',
  'HH_GERACAO': '12:18:46',
  'ANO_ELEICAO': 2020,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 426,
  'DS_ELEICAO': 'Eleições Municipais 2020',
  'DT_ELEICAO': '15/11/2020',
  'TP_ABRANGENCIA': 'MUNICIPAL',
  'SG_UF': 'PE',
  'SG_UE': 23086,
  'NM_UE': 'VERTENTE DO LÉRIO',
  'CD_CARGO': 13,
  'DS_CARGO': 'VEREADOR',
  'SQ_CANDIDATO': 170000971541,
  'NR_CANDIDATO': 14555,
  'NM_CANDIDATO': 'SEVERINO DA SILVA NASCIMENTO',
  'NM_URNA_CANDIDATO': 'SEVERINO DO POVO',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 2541370407,
  'NM_EMAIL': 'JOSILEAL@BOL.COM.BR',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 14,
  'SG_PARTIDO': 'PTB',
  'NM_PARTIDO': 'PARTIDO TRABALHISTA BRASILEIRO',
  'SQ_COLIGACAO': 170000113103,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'PTB',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PE',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'VERTENTE DO LÉRIO',
  'DT_NASCIMENTO': '10/12/1976',
  'NR_IDADE_DATA_POSSE': 44,
  'NR_TITULO_ELEITORAL_CANDIDATO': 48234550892,
  'CD_GENERO': 2,
  'DS_GENERO': 'MASCULINO',
  'CD_GRAU_INSTRUCAO': 4,
  'DS_GRAU_INSTRUCAO': 'ENSINO FUNDAMENTAL COMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 3,
  'DS_COR_RACA': 'PARDA',
  'CD_OCUPACAO': 999,
  'DS_OCUPACAO': 'OUTROS',
  'VR_DESPESA_MAX_CAMPANHA': 12307.75,
  'CD_SIT_TOT_TURNO': 2,
  'DS_SIT_TOT_TURNO': 'ELEITO POR QP',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6002560820206170034,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM'},
 {'DT_GERACAO': '22/05/2021',
  'HH_GERACAO': '12:18:46',
  'ANO_ELEICAO': 2020,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 426,
  'DS_ELEICAO': 'Eleições Municipais 2020',
  'DT_ELEICAO': '15/11/2020',
  'TP_ABRANGENCIA': 'MUNICIPAL',
  'SG_UF': 'PE',
  'SG_UE': 24554,
  'NM_UE': 'ITAQUITINGA',
  'CD_CARGO': 13,
  'DS_CARGO': 'VEREADOR',
  'SQ_CANDIDATO': 170000990967,
  'NR_CANDIDATO': 10456,
  'NM_CANDIDATO': 'MARTA MARIA LEMOS DA SILVA',
  'NM_URNA_CANDIDATO': 'MARTA LEMOS',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 42672481415,
  'NM_EMAIL': 'LUANMARTINSCASTRO@GMAIL.COM',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 10,
  'SG_PARTIDO': 'REPUBLICANOS',
  'NM_PARTIDO': 'REPUBLICANOS',
  'SQ_COLIGACAO': 170000116162,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'REPUBLICANOS',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PE',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'GOIANA',
  'DT_NASCIMENTO': '07/09/1957',
  'NR_IDADE_DATA_POSSE': 63,
  'NR_TITULO_ELEITORAL_CANDIDATO': 34202470817,
  'CD_GENERO': 4,
  'DS_GENERO': 'FEMININO',
  'CD_GRAU_INSTRUCAO': 6,
  'DS_GRAU_INSTRUCAO': 'ENSINO MÉDIO COMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 1,
  'DS_COR_RACA': 'BRANCA',
  'CD_OCUPACAO': 999,
  'DS_OCUPACAO': 'OUTROS',
  'VR_DESPESA_MAX_CAMPANHA': 12307.75,
  'CD_SIT_TOT_TURNO': 5,
  'DS_SIT_TOT_TURNO': 'SUPLENTE',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6003827620206170125,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM'},
 {'DT_GERACAO': '22/05/2021',
  'HH_GERACAO': '12:18:46',
  'ANO_ELEICAO': 2020,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 426,
  'DS_ELEICAO': 'Eleições Municipais 2020',
  'DT_ELEICAO': '15/11/2020',
  'TP_ABRANGENCIA': 'MUNICIPAL',
  'SG_UF': 'PE',
  'SG_UE': 23264,
  'NM_UE': 'JATOBÁ',
  'CD_CARGO': 13,
  'DS_CARGO': 'VEREADOR',
  'SQ_CANDIDATO': 170000657782,
  'NR_CANDIDATO': 17777,
  'NM_CANDIDATO': 'SEBASTIÃO DA COSTA COELHO',
  'NM_URNA_CANDIDATO': 'SEBASTIÃO COSTA',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 13521691420,
  'NM_EMAIL': 'PSLJATOBA17@GMAIL.COM',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 17,
  'SG_PARTIDO': 'PSL',
  'NM_PARTIDO': 'PARTIDO SOCIAL LIBERAL',
  'SQ_COLIGACAO': 170000058640,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'PSL',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PE',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'PETROLÂNDIA',
  'DT_NASCIMENTO': '22/01/1953',
  'NR_IDADE_DATA_POSSE': 67,
  'NR_TITULO_ELEITORAL_CANDIDATO': 20067470809,
  'CD_GENERO': 2,
  'DS_GENERO': 'MASCULINO',
  'CD_GRAU_INSTRUCAO': 6,
  'DS_GRAU_INSTRUCAO': 'ENSINO MÉDIO COMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 1,
  'DS_COR_RACA': 'BRANCA',
  'CD_OCUPACAO': 923,
  'DS_OCUPACAO': 'APOSENTADO (EXCETO SERVIDOR PÚBLICO)',
  'VR_DESPESA_MAX_CAMPANHA': 12307.75,
  'CD_SIT_TOT_TURNO': 4,
  'DS_SIT_TOT_TURNO': 'NÃO ELEITO',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6000476820206170089,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM'},
 {'DT_GERACAO': '22/05/2021',
  'HH_GERACAO': '12:18:46',
  'ANO_ELEICAO': 2020,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 426,
  'DS_ELEICAO': 'Eleições Municipais 2020',
  'DT_ELEICAO': '15/11/2020',
  'TP_ABRANGENCIA': 'MUNICIPAL',
  'SG_UF': 'PE',
  'SG_UE': 25216,
  'NM_UE': 'PETROLINA',
  'CD_CARGO': 13,
  'DS_CARGO': 'VEREADOR',
  'SQ_CANDIDATO': 170001179423,
  'NR_CANDIDATO': 17222,
  'NM_CANDIDATO': 'DÁRIO CÉSAR MOREIRA',
  'NM_URNA_CANDIDATO': 'DÁRIO MORORÓ',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 7141808400,
  'NM_EMAIL': 'DARIOMORORO@GMAIL.COM',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 17,
  'SG_PARTIDO': 'PSL',
  'NM_PARTIDO': 'PARTIDO SOCIAL LIBERAL',
  'SQ_COLIGACAO': 170000145155,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'PSL',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PE',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'SERRA TALHADA',
  'DT_NASCIMENTO': '27/09/1989',
  'NR_IDADE_DATA_POSSE': 31,
  'NR_TITULO_ELEITORAL_CANDIDATO': 74125090850,
  'CD_GENERO': 2,
  'DS_GENERO': 'MASCULINO',
  'CD_GRAU_INSTRUCAO': 6,
  'DS_GRAU_INSTRUCAO': 'ENSINO MÉDIO COMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 3,
  'DS_COR_RACA': 'PARDA',
  'CD_OCUPACAO': 601,
  'DS_OCUPACAO': 'AGRICULTOR',
  'VR_DESPESA_MAX_CAMPANHA': 131218.52,
  'CD_SIT_TOT_TURNO': 4,
  'DS_SIT_TOT_TURNO': 'NÃO ELEITO',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6004176520206170083,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM'},
 {'DT_GERACAO': '22/05/2021',
  'HH_GERACAO': '12:18:46',
  'ANO_ELEICAO': 2020,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 426,
  'DS_ELEICAO': 'Eleições Municipais 2020',
  'DT_ELEICAO': '15/11/2020',
  'TP_ABRANGENCIA': 'MUNICIPAL',
  'SG_UF': 'PE',
  'SG_UE': 24350,
  'NM_UE': 'IGARASSU',
  'CD_CARGO': 13,
  'DS_CARGO': 'VEREADOR',
  'SQ_CANDIDATO': 170000944712,
  'NR_CANDIDATO': 65455,
  'NM_CANDIDATO': 'COSME CORDEIRO PAULINO',
  'NM_URNA_CANDIDATO': 'COSME DOS MARCOS',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 59259310415,
  'NM_EMAIL': 'RCBUARQUE@GMAIL.COM',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 65,
  'SG_PARTIDO': 'PC do B',
  'NM_PARTIDO': 'PARTIDO COMUNISTA DO BRASIL',
  'SQ_COLIGACAO': 170000109245,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'PC do B',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PE',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'IGARASSU',
  'DT_NASCIMENTO': '27/07/1964',
  'NR_IDADE_DATA_POSSE': 56,
  'NR_TITULO_ELEITORAL_CANDIDATO': 23349670809,
  'CD_GENERO': 2,
  'DS_GENERO': 'MASCULINO',
  'CD_GRAU_INSTRUCAO': 4,
  'DS_GRAU_INSTRUCAO': 'ENSINO FUNDAMENTAL COMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 3,
  'DS_COR_RACA': 'PARDA',
  'CD_OCUPACAO': 169,
  'DS_OCUPACAO': 'COMERCIANTE',
  'VR_DESPESA_MAX_CAMPANHA': 39466.41,
  'CD_SIT_TOT_TURNO': 5,
  'DS_SIT_TOT_TURNO': 'SUPLENTE',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6002772520206170085,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM'},
 {'DT_GERACAO': '22/05/2021',
  'HH_GERACAO': '12:18:46',
  'ANO_ELEICAO': 2020,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 426,
  'DS_ELEICAO': 'Eleições Municipais 2020',
  'DT_ELEICAO': '15/11/2020',
  'TP_ABRANGENCIA': 'MUNICIPAL',
  'SG_UF': 'PE',
  'SG_UE': 25615,
  'NM_UE': 'SÃO CAITANO',
  'CD_CARGO': 13,
  'DS_CARGO': 'VEREADOR',
  'SQ_CANDIDATO': 170000828281,
  'NR_CANDIDATO': 17888,
  'NM_CANDIDATO': 'SEVERINO VIEIRA RAMOS NETO',
  'NM_URNA_CANDIDATO': 'NETO RAMOS',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 4198870403,
  'NM_EMAIL': 'ANDREDIREITOS@HOTMAIL.COM',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 17,
  'SG_PARTIDO': 'PSL',
  'NM_PARTIDO': 'PARTIDO SOCIAL LIBERAL',
  'SQ_COLIGACAO': 170000087156,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'PSL',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PE',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'BELO JARDIM',
  'DT_NASCIMENTO': '19/05/1983',
  'NR_IDADE_DATA_POSSE': 37,
  'NR_TITULO_ELEITORAL_CANDIDATO': 61604600876,
  'CD_GENERO': 2,
  'DS_GENERO': 'MASCULINO',
  'CD_GRAU_INSTRUCAO': 5,
  'DS_GRAU_INSTRUCAO': 'ENSINO MÉDIO INCOMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 3,
  'DS_COR_RACA': 'PARDA',
  'CD_OCUPACAO': 169,
  'DS_OCUPACAO': 'COMERCIANTE',
  'VR_DESPESA_MAX_CAMPANHA': 41468.76,
  'CD_SIT_TOT_TURNO': 2,
  'DS_SIT_TOT_TURNO': 'ELEITO POR QP',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6001960520206170044,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM'},
 {'DT_GERACAO': '22/05/2021',
  'HH_GERACAO': '12:18:46',
  'ANO_ELEICAO': 2020,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 426,
  'DS_ELEICAO': 'Eleições Municipais 2020',
  'DT_ELEICAO': '15/11/2020',
  'TP_ABRANGENCIA': 'MUNICIPAL',
  'SG_UF': 'PE',
  'SG_UE': 24910,
  'NM_UE': 'OLINDA',
  'CD_CARGO': 13,
  'DS_CARGO': 'VEREADOR',
  'SQ_CANDIDATO': 170000942736,
  'NR_CANDIDATO': 27000,
  'NM_CANDIDATO': 'BRUNA RAFAELLA DA SILVA FREITAS',
  'NM_URNA_CANDIDATO': 'BRUNA FREITAS',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 9906778423,
  'NM_EMAIL': 'BRUNA.R.FREITAS@BOL.COM.BR',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 27,
  'SG_PARTIDO': 'DC',
  'NM_PARTIDO': 'DEMOCRACIA CRISTÃ',
  'SQ_COLIGACAO': 170000108952,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'DC',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PE',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'MORENO',
  'DT_NASCIMENTO': '28/08/1991',
  'NR_IDADE_DATA_POSSE': 29,
  'NR_TITULO_ELEITORAL_CANDIDATO': 81203280841,
  'CD_GENERO': 4,
  'DS_GENERO': 'FEMININO',
  'CD_GRAU_INSTRUCAO': 6,
  'DS_GRAU_INSTRUCAO': 'ENSINO MÉDIO COMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 3,
  'DS_COR_RACA': 'PARDA',
  'CD_OCUPACAO': 999,
  'DS_OCUPACAO': 'OUTROS',
  'VR_DESPESA_MAX_CAMPANHA': 105385.98,
  'CD_SIT_TOT_TURNO': 4,
  'DS_SIT_TOT_TURNO': 'NÃO ELEITO',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6003347420206170010,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM'},
 {'DT_GERACAO': '22/05/2021',
  'HH_GERACAO': '12:18:46',
  'ANO_ELEICAO': 2020,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 426,
  'DS_ELEICAO': 'Eleições Municipais 2020',
  'DT_ELEICAO': '15/11/2020',
  'TP_ABRANGENCIA': 'MUNICIPAL',
  'SG_UF': 'PE',
  'SG_UE': 23795,
  'NM_UE': 'CARPINA',
  'CD_CARGO': 13,
  'DS_CARGO': 'VEREADOR',
  'SQ_CANDIDATO': 170001209832,
  'NR_CANDIDATO': 36123,
  'NM_CANDIDATO': 'MARIA MADALENA NASCIMENTO DE SOUSA',
  'NM_URNA_CANDIDATO': 'IRMÃ MADALENA',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 35870125472,
  'NM_EMAIL': 'BETACRISS_42@HOTMAIL.COM',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 36,
  'SG_PARTIDO': 'PTC',
  'NM_PARTIDO': 'PARTIDO TRABALHISTA CRISTÃO',
  'SQ_COLIGACAO': 170000148880,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'PTC',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PE',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'TIMBAÚBA',
  'DT_NASCIMENTO': '14/05/1958',
  'NR_IDADE_DATA_POSSE': 62,
  'NR_TITULO_ELEITORAL_CANDIDATO': 8997220850,
  'CD_GENERO': 4,
  'DS_GENERO': 'FEMININO',
  'CD_GRAU_INSTRUCAO': 8,
  'DS_GRAU_INSTRUCAO': 'SUPERIOR COMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 3,
  'DS_COR_RACA': 'PARDA',
  'CD_OCUPACAO': 296,
  'DS_OCUPACAO': 'SERVIDOR PÚBLICO FEDERAL',
  'VR_DESPESA_MAX_CAMPANHA': 49954.88,
  'CD_SIT_TOT_TURNO': 5,
  'DS_SIT_TOT_TURNO': 'SUPLENTE',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6002296720206170020,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM'}]

# %%
anos_18_24 = []
anos_25_34 = []
anos_35_44 = []
anos_45_54 = []
anos_55_64 = []
anos_acima_64 = []

# %%
for candidata in candidaturas:
    
    if candidata['NR_IDADE_DATA_POSSE'] >= 18 and candidata['NR_IDADE_DATA_POSSE'] <= 24:
        anos_18_24.append(candidata['NM_CANDIDATO'])
    elif candidata['NR_IDADE_DATA_POSSE'] >= 25 and candidata['NR_IDADE_DATA_POSSE'] <= 34:
        anos_25_34.append(candidata['NM_CANDIDATO'])
    elif candidata['NR_IDADE_DATA_POSSE'] >= 35 and candidata['NR_IDADE_DATA_POSSE'] <= 44:
        anos_35_44.append(candidata['NM_CANDIDATO'])
    elif candidata['NR_IDADE_DATA_POSSE'] >= 45 and candidata['NR_IDADE_DATA_POSSE'] <= 54:
        anos_45_54.append(candidata['NM_CANDIDATO'])
    elif candidata['NR_IDADE_DATA_POSSE'] >= 55 and candidata['NR_IDADE_DATA_POSSE'] <= 64:
        anos_55_64.append(candidata['NM_CANDIDATO'])
    else:
        anos_acima_64.append(candidata['NM_CANDIDATO'])

# %%
print(f'Candidaturas por faixa etária:')
print(f'18-24 anos: {anos_18_24}')
print(f'25-34 anos: {anos_25_34}')
print(f'35-44 anos: {anos_35_44}')
print(f'45-54 anos: {anos_45_54}')
print(f'55-64 anos: {anos_55_64}')
print(f'acima 64 anos: {anos_acima_64}')
# Out:
# Candidaturas por faixa etária:
# 18-24 anos: []
# 25-34 anos: ['DÁRIO CÉSAR MOREIRA', 'BRUNA RAFAELLA DA SILVA FREITAS']
# 35-44 anos: ['DANIELA TAMARA SANTOS SILVA', 'SEVERINO DA SILVA NASCIMENTO', 'SEVERINO VIEIRA RAMOS NETO']
# 45-54 anos: []
# 55-64 anos: ['SEVERINO ALVES DA SILVA FILHO', 'MARTA MARIA LEMOS DA SILVA', 'COSME CORDEIRO PAULINO', 'MARIA MADALENA NASCIMENTO DE SOUSA']
# acima 64 anos: ['SEBASTIÃO DA COSTA COELHO']

# %%
#Usando o mesmo dicionário do exercício anterior. Agrupe as candidaturas em "feminino" e "masculino" usando a chave "DS_GENERO".

# %%
feminino = []
masculino = []

# %%
for candidata in candidaturas:
    if candidata['DS_GENERO'] == 'FEMININO' and  (candidata['DS_GENERO'] == 'MASCULINO'):
        genero_cand.append(candidata['NM_CANDIDATO'])
    else:
       print(candidata['NM_CANDIDATO'])
# Out:
# DANIELA TAMARA SANTOS SILVA
# SEVERINO ALVES DA SILVA FILHO
# SEVERINO DA SILVA NASCIMENTO
# MARTA MARIA LEMOS DA SILVA
# SEBASTIÃO DA COSTA COELHO
# DÁRIO CÉSAR MOREIRA
# COSME CORDEIRO PAULINO
# SEVERINO VIEIRA RAMOS NETO
# BRUNA RAFAELLA DA SILVA FREITAS
# MARIA MADALENA NASCIMENTO DE SOUSA

# %% [markdown]
# Exercício dia 10/08/2021 Aula ao Vivo

# %%
numero_1 = int(input('Insira um número positivo: '))
numero_2 = int(input('Insira outro número positivo: '))
# Out:
# Insira um número positivo: 6
# Insira outro número positivo: 13

# %%
lista = list(range(numero_1, numero_2))
print(lista)
# Out:
# [6, 7, 8, 9, 10, 11, 12]

# %%
lista_atual = []
for n in lista:
    if n % 3 == 0:
        lista_atual.append('Tecnologia')
    elif n % 5 ==0:
        lista_atual.append('Cívica')
    elif n % 3 == 0 and n % 5 ==0:
        lista_atual.append('Tecnologia Cívica')
    else:lista_atual.append (n)

# %%
print(lista_atual)
# Out:
# ['Tecnologia', 7, 8, 'Tecnologia', 'Cívica', 11, 'Tecnologia']

# %%
lista_atual = []
for n in lista:
    if n % 3 == 0 and n % 5 ==0:
        lista_atual.append('Tecnologia Cívica')
    elif n % 3 == 0:
        lista_atual.append('Tecnologia')
    elif n % 5 ==0:
        lista_atual.append('Cívica')
    else:lista_atual.append (n)
print(lista_atual)
# Out:
# ['Tecnologia', 7, 8, 'Tecnologia', 'Cívica', 11, 'Tecnologia']

# %% [markdown]
# Módulo 1, Aula 5 Pacotes

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import zipfile

# %%
candidaturas_pe = pd.read_csv('/content/drive/MyDrive/Python para inovação civica/consulta_cand_2020_PE.csv', 
                              encoding='Latin-1', sep=';')

# %%
pd.options.display.max_columns= None

# %%
candidaturas_pe.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 1  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 2  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 3  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 4  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
#
#    NR_TURNO  CD_ELEICAO                DS_ELEICAO  DT_ELEICAO TP_ABRANGENCIA  \
# 0         1         426  Eleições Municipais 2020  15/11/2020      MUNICIPAL
# 1         1         426  Eleições Municipais 2020  15/11/2020      MUNICIPAL
# 2         1         426  Eleições Municipais 2020  15/11/2020      MUNICIPAL
# 3         1         426  Eleições Municipais 2020  15/11/2020      MUNICIPAL
# 4         1         426  Eleições Municipais 2020  15/11/2020      MUNICIPAL
#
#   SG_UF  SG_UE        NM_UE  CD_CARGO  DS_CARGO  SQ_CANDIDATO  NR_CANDIDATO  \
# 0    PE  23817      CARUARU        13  VEREADOR  170001231149         17008
# 1    PE  23094  ÁGUAS BELAS        13  VEREADOR  170000800795         15515
# 2    PE  25313       RECIFE        13  VEREADOR  170000836659         25033
# 3    PE  24970     OURICURI        13  VEREADOR  170000648896         45777
# 4    PE  24996     PALMARES        13  VEREADOR  170001129430         90090
#
#                         NM_CANDIDATO         NM_URNA_CANDIDATO  \
# 0    MARIA DE LOURDES ALVES DE SOUZA   DONA LOURDES DA BONANÇA
# 1  JOSÉ MAREVALDO BARROS DE OLIVEIRA       MAREVALDO DA RUA 15
# 2            JOSÉ AGNIS PERKLES RÊGO                JOSÉ AGNIS
# 3               DELVANI SILVA SOBRAL           DELVANIA SOBRAL
# 4       MARILENE SHEILLA DE OLIVEIRA  SHEILLA DO MEIO AMBIENTE
#
#   NM_SOCIAL_CANDIDATO  NR_CPF_CANDIDATO                     NM_EMAIL  \
# 0              #NULO#       12310328472   NG_CONSULTORIA@HOTMAIL.COM
# 1              #NULO#       59971576449  MDBABCAMPANHA2020@GMAIL.COM
# 2              #NULO#       61079570730  DIRETORIODEMREC25@GMAIL.COM
# 3              #NULO#       68068123415  DELVANIA_SOBRAL@HOTMAIL.COM
# 4              #NULO#        4522160445      MARC_GUEDES@HOTMAIL.COM
#
#    CD_SITUACAO_CANDIDATURA DS_SITUACAO_CANDIDATURA  CD_DETALHE_SITUACAO_CAND  \
# 0                       12                    APTO                         2
# 1                       12                    APTO                         2
# 2                       12                    APTO                         2
# 3                       12                    APTO                         2
# 4                        3                  INAPTO                         6
#
#   DS_DETALHE_SITUACAO_CAND    TP_AGREMIACAO  NR_PARTIDO SG_PARTIDO  \
# 0                 DEFERIDO  PARTIDO ISOLADO          17        PSL
# 1                 DEFERIDO  PARTIDO ISOLADO          15        MDB
# 2                 DEFERIDO  PARTIDO ISOLADO          25        DEM
# 3                 DEFERIDO  PARTIDO ISOLADO          45       PSDB
# 4                 RENÚNCIA  PARTIDO ISOLADO          90       PROS
#
#                                 NM_PARTIDO  SQ_COLIGACAO     NM_COLIGACAO  \
# 0                   PARTIDO SOCIAL LIBERAL  170000152093  PARTIDO ISOLADO
# 1         MOVIMENTO DEMOCRÁTICO BRASILEIRO  170000078841  PARTIDO ISOLADO
# 2                               DEMOCRATAS  170000088761  PARTIDO ISOLADO
# 3  PARTIDO DA SOCIAL DEMOCRACIA BRASILEIRA  170000057628  PARTIDO ISOLADO
# 4      PARTIDO REPUBLICANO DA ORDEM SOCIAL  170000136900  PARTIDO ISOLADO
#
#   DS_COMPOSICAO_COLIGACAO  CD_NACIONALIDADE           DS_NACIONALIDADE  \
# 0                     PSL                 1            BRASILEIRA NATA
# 1                     MDB                 1            BRASILEIRA NATA
# 2                     DEM                 1            BRASILEIRA NATA
# 3                    PSDB                 2  BRASILEIRA (NATURALIZADA)
# 4                    PROS                 1            BRASILEIRA NATA
#
#   SG_UF_NASCIMENTO  CD_MUNICIPIO_NASCIMENTO NM_MUNICIPIO_NASCIMENTO  \
# 0               PE                       -3                  RECIFE
# 1               PE                       -3             ÁGUAS BELAS
# 2               RJ                       -3          RIO DE JANEIRO
# 3               PE                       -3                OURICURI
# 4               AL                       -3                  MACEIÓ
#
#   DT_NASCIMENTO  NR_IDADE_DATA_POSSE  NR_TITULO_ELEITORAL_CANDIDATO  \
# 0    09/10/1952                   68                     3341960884
# 1    28/09/1969                   51                    34158500825
# 2    27/05/1962                   58                    73197820337
# 3    10/03/1971                   49                    40086930833
# 4    26/07/1973                   47                    54096200809
#
#    CD_GENERO  DS_GENERO  CD_GRAU_INSTRUCAO              DS_GRAU_INSTRUCAO  \
# 0          4   FEMININO                  6          ENSINO MÉDIO COMPLETO
# 1          2  MASCULINO                  3  ENSINO FUNDAMENTAL INCOMPLETO
# 2          2  MASCULINO                  8              SUPERIOR COMPLETO
# 3          4   FEMININO                  8              SUPERIOR COMPLETO
# 4          4   FEMININO                  8              SUPERIOR COMPLETO
#
#    CD_ESTADO_CIVIL DS_ESTADO_CIVIL  CD_COR_RACA DS_COR_RACA  CD_OCUPACAO  \
# 0                3       CASADO(A)            3       PARDA          999
# 1                3       CASADO(A)            3       PARDA          999
# 2                9   DIVORCIADO(A)            1      BRANCA          131
# 3                1     SOLTEIRO(A)            3       PARDA          298
# 4                1     SOLTEIRO(A)            3       PARDA          999
#
#                   DS_OCUPACAO  VR_DESPESA_MAX_CAMPANHA  CD_SIT_TOT_TURNO  \
# 0                      OUTROS                149376.80                 5
# 1                      OUTROS                 48405.01                 5
# 2                    ADVOGADO               1011149.65                 5
# 3  SERVIDOR PÚBLICO MUNICIPAL                 26120.37                 2
# 4                      OUTROS                 26666.50                -1
#
#   DS_SIT_TOT_TURNO ST_REELEICAO ST_DECLARAR_BENS  NR_PROTOCOLO_CANDIDATURA  \
# 0         SUPLENTE            N                N                        -1
# 1         SUPLENTE            N                S                        -1
# 2         SUPLENTE            N                S                        -1
# 3    ELEITO POR QP            N                S                        -1
# 4           #NULO#            N                S                        -1
#
#            NR_PROCESSO  CD_SITUACAO_CANDIDATO_PLEITO  \
# 0  6004724720206170105                             2
# 1  6000665220206170064                             2
# 2  6001433520206170008                             2
# 3  6001353020206170082                             2
# 4  6002360820206170037                            -1
#
#   DS_SITUACAO_CANDIDATO_PLEITO  CD_SITUACAO_CANDIDATO_URNA  \
# 0                     DEFERIDO                           2
# 1                     DEFERIDO                           2
# 2                     DEFERIDO                           2
# 3                     DEFERIDO                           2
# 4                       #NULO#                          -1
#
#   DS_SITUACAO_CANDIDATO_URNA ST_CANDIDATO_INSERIDO_URNA
# 0                   DEFERIDO                        SIM
# 1                   DEFERIDO                        SIM
# 2                   DEFERIDO                        SIM
# 3                   DEFERIDO                        SIM
# 4                     #NULO#                        NÃO

# %%
candidaturas_pe.shape
# Out:
# (21101, 63)

# %% [markdown]
# Quantas candidaturas houveram no seu município nas eleições de 2020?

# %%
with zipfile.ZipFile('/content/drive/MyDrive/Python para inovação civica/consulta_cand_2020.zip') as z:
  print(*z.namelist(), sep='\n')
# Out:
# consulta_cand_2020_AC.csv
# consulta_cand_2020_AL.csv
# consulta_cand_2020_AM.csv
# consulta_cand_2020_AP.csv
# consulta_cand_2020_BA.csv
# consulta_cand_2020_CE.csv
# consulta_cand_2020_ES.csv
# consulta_cand_2020_GO.csv
# consulta_cand_2020_MA.csv
# consulta_cand_2020_MG.csv
# consulta_cand_2020_MS.csv
# consulta_cand_2020_MT.csv
# consulta_cand_2020_PA.csv
# consulta_cand_2020_PB.csv
# consulta_cand_2020_PE.csv
# consulta_cand_2020_PI.csv
# consulta_cand_2020_PR.csv
# consulta_cand_2020_RJ.csv
# consulta_cand_2020_RN.csv
# consulta_cand_2020_RO.csv
# consulta_cand_2020_RR.csv
# consulta_cand_2020_RS.csv
# consulta_cand_2020_SC.csv
# consulta_cand_2020_SE.csv
# consulta_cand_2020_SP.csv
# consulta_cand_2020_TO.csv
# consulta_cand_2020_BRASIL.csv
# leiame.pdf

# %%
with zipfile.ZipFile('/content/drive/MyDrive/Python para inovação civica/consulta_cand_2020.zip') as z:
    with z.open('consulta_cand_2020_SP.csv') as f:
     df = pd.read_csv(f, sep=';', encoding='ISO-8859-1')

# %%
df_sp = df

# %%
df_sp.head(3)
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  09/08/2021   07:18:31         2020                2  ELEIÇÃO ORDINÁRIA
# 1  09/08/2021   07:18:31         2020                2  ELEIÇÃO ORDINÁRIA
# 2  09/08/2021   07:18:31         2020                2  ELEIÇÃO ORDINÁRIA
#
#    NR_TURNO  CD_ELEICAO                DS_ELEICAO  DT_ELEICAO TP_ABRANGENCIA  \
# 0         1         426  Eleições Municipais 2020  15/11/2020      MUNICIPAL
# 1         1         426  Eleições Municipais 2020  15/11/2020      MUNICIPAL
# 2         1         426  Eleições Municipais 2020  15/11/2020      MUNICIPAL
#
#   SG_UF  SG_UE                 NM_UE  CD_CARGO  DS_CARGO  SQ_CANDIDATO  \
# 0    SP  62570             BRODOWSKI        13  VEREADOR  250001087134
# 1    SP  72311  VARGEM GRANDE DO SUL        13  VEREADOR  250001087197
# 2    SP  67431      MURUTINGA DO SUL        13  VEREADOR  250001121615
#
#    NR_CANDIDATO                  NM_CANDIDATO  NM_URNA_CANDIDATO  \
# 0         40999               LEONARDO ARRUDA             LEOZÃO
# 1         15300     DEVANIR APARECIDO MAPELLI            MAPELLI
# 2         11133  JACKELINE APARECIDA LAURINDO  JACK DA SACOLINHA
#
#   NM_SOCIAL_CANDIDATO  NR_CPF_CANDIDATO  \
# 0              #NULO#       70841810168
# 1              #NULO#       13743711818
# 2              #NULO#       27118188883
#
#                                       NM_EMAIL  CD_SITUACAO_CANDIDATURA  \
# 0                    LEOARRUDA0106@HOTMAIL.COM                       12
# 1                        DEVANIR6157@GMAIL.COM                       12
# 2  ESCRITORIOPRCONTABILSUZANAPOLIS@HOTMAIL.COM                       12
#
#   DS_SITUACAO_CANDIDATURA  CD_DETALHE_SITUACAO_CAND DS_DETALHE_SITUACAO_CAND  \
# 0                    APTO                         2                 DEFERIDO
# 1                    APTO                         2                 DEFERIDO
# 2                    APTO                         2                 DEFERIDO
#
#      TP_AGREMIACAO  NR_PARTIDO SG_PARTIDO                        NM_PARTIDO  \
# 0  PARTIDO ISOLADO          40        PSB     PARTIDO SOCIALISTA BRASILEIRO
# 1  PARTIDO ISOLADO          15        MDB  MOVIMENTO DEMOCRÁTICO BRASILEIRO
# 2  PARTIDO ISOLADO          11         PP                     PROGRESSISTAS
#
#    SQ_COLIGACAO     NM_COLIGACAO DS_COMPOSICAO_COLIGACAO  CD_NACIONALIDADE  \
# 0  250000131659  PARTIDO ISOLADO                     PSB                 1
# 1  250000131664  PARTIDO ISOLADO                     MDB                 1
# 2  250000135976  PARTIDO ISOLADO                      PP                 1
#
#   DS_NACIONALIDADE SG_UF_NASCIMENTO  CD_MUNICIPIO_NASCIMENTO  \
# 0  BRASILEIRA NATA               SP                       -3
# 1  BRASILEIRA NATA               SP                       -3
# 2  BRASILEIRA NATA               SP                       -3
#
#   NM_MUNICIPIO_NASCIMENTO DT_NASCIMENTO  NR_IDADE_DATA_POSSE  \
# 0               BRODOWSKI    01/06/1982                   38
# 1  SÃO SEBASTIÃO DA GRAMA    23/05/1970                   50
# 2               SÃO PAULO    22/06/1979                   41
#
#    NR_TITULO_ELEITORAL_CANDIDATO  CD_GENERO  DS_GENERO  CD_GRAU_INSTRUCAO  \
# 0                   290048760116          2  MASCULINO                  6
# 1                   180800210132          2  MASCULINO                  3
# 2                   229560800167          4   FEMININO                  3
#
#                DS_GRAU_INSTRUCAO  CD_ESTADO_CIVIL DS_ESTADO_CIVIL  \
# 0          ENSINO MÉDIO COMPLETO                1     SOLTEIRO(A)
# 1  ENSINO FUNDAMENTAL INCOMPLETO                3       CASADO(A)
# 2  ENSINO FUNDAMENTAL INCOMPLETO                1     SOLTEIRO(A)
#
#    CD_COR_RACA DS_COR_RACA  CD_OCUPACAO           DS_OCUPACAO  \
# 0            1      BRANCA          537  MOTORISTA PARTICULAR
# 1            1      BRANCA          999                OUTROS
# 2            3       PARDA          999                OUTROS
#
#    VR_DESPESA_MAX_CAMPANHA  CD_SIT_TOT_TURNO DS_SIT_TOT_TURNO ST_REELEICAO  \
# 0                 12307.75                 5         SUPLENTE            N
# 1                 16384.17                 5         SUPLENTE            N
# 2                 12307.75                 5         SUPLENTE            N
#
#   ST_DECLARAR_BENS  NR_PROTOCOLO_CANDIDATURA          NR_PROCESSO  \
# 0                S                        -1  6002303320206260204
# 1                N                        -1  6002582320206260229
# 2                S                        -1  6002659320206260009
#
#    CD_SITUACAO_CANDIDATO_PLEITO DS_SITUACAO_CANDIDATO_PLEITO  \
# 0                             2                     DEFERIDO
# 1                             2                     DEFERIDO
# 2                             2                     DEFERIDO
#
#    CD_SITUACAO_CANDIDATO_URNA DS_SITUACAO_CANDIDATO_URNA  \
# 0                           2                   DEFERIDO
# 1                           2                   DEFERIDO
# 2                           2                   DEFERIDO
#
#   ST_CANDIDATO_INSERIDO_URNA
# 0                        SIM
# 1                        SIM
# 2                        SIM

# %%
df_sp.columns.values
# Out:
# array(['DT_GERACAO', 'HH_GERACAO', 'ANO_ELEICAO', 'CD_TIPO_ELEICAO',
#        'NM_TIPO_ELEICAO', 'NR_TURNO', 'CD_ELEICAO', 'DS_ELEICAO',
#        'DT_ELEICAO', 'TP_ABRANGENCIA', 'SG_UF', 'SG_UE', 'NM_UE',
#        'CD_CARGO', 'DS_CARGO', 'SQ_CANDIDATO', 'NR_CANDIDATO',
#        'NM_CANDIDATO', 'NM_URNA_CANDIDATO', 'NM_SOCIAL_CANDIDATO',
#        'NR_CPF_CANDIDATO', 'NM_EMAIL', 'CD_SITUACAO_CANDIDATURA',
#        'DS_SITUACAO_CANDIDATURA', 'CD_DETALHE_SITUACAO_CAND',
#        'DS_DETALHE_SITUACAO_CAND', 'TP_AGREMIACAO', 'NR_PARTIDO',
#        'SG_PARTIDO', 'NM_PARTIDO', 'SQ_COLIGACAO', 'NM_COLIGACAO',
#        'DS_COMPOSICAO_COLIGACAO', 'CD_NACIONALIDADE', 'DS_NACIONALIDADE',
#        'SG_UF_NASCIMENTO', 'CD_MUNICIPIO_NASCIMENTO',
#        'NM_MUNICIPIO_NASCIMENTO', 'DT_NASCIMENTO', 'NR_IDADE_DATA_POSSE',
#        'NR_TITULO_ELEITORAL_CANDIDATO', 'CD_GENERO', 'DS_GENERO',
#        'CD_GRAU_INSTRUCAO', 'DS_GRAU_INSTRUCAO', 'CD_ESTADO_CIVIL',
#        'DS_ESTADO_CIVIL', 'CD_COR_RACA', 'DS_COR_RACA', 'CD_OCUPACAO',
#        'DS_OCUPACAO', 'VR_DESPESA_MAX_CAMPANHA', 'CD_SIT_TOT_TURNO',
#        'DS_SIT_TOT_TURNO', 'ST_REELEICAO', 'ST_DECLARAR_BENS',
#        'NR_PROTOCOLO_CANDIDATURA', 'NR_PROCESSO',
#        'CD_SITUACAO_CANDIDATO_PLEITO', 'DS_SITUACAO_CANDIDATO_PLEITO',
#        'CD_SITUACAO_CANDIDATO_URNA', 'DS_SITUACAO_CANDIDATO_URNA',
#        'ST_CANDIDATO_INSERIDO_URNA'], dtype=object)

# %%
 df_sp[df_sp['NM_MUNICIPIO_NASCIMENTO'] == 'SÃO PAULO'].count()
# Out:
# DT_GERACAO                      9201
# HH_GERACAO                      9201
# ANO_ELEICAO                     9201
# CD_TIPO_ELEICAO                 9201
# NM_TIPO_ELEICAO                 9201
#                                 ...
# CD_SITUACAO_CANDIDATO_PLEITO    9201
# DS_SITUACAO_CANDIDATO_PLEITO    9201
# CD_SITUACAO_CANDIDATO_URNA      9201
# DS_SITUACAO_CANDIDATO_URNA      9201
# ST_CANDIDATO_INSERIDO_URNA      9201
# Length: 63, dtype: int64

# %% [markdown]
# Módulo 1, aula 7

# %%
import glob

# %%
dados_todos_estados = glob.glob('/content/drive/MyDrive/Python para inovação civica/conjunto_dados/*.csv')
print(dados_todos_estados)
# Out:
# ['/content/drive/MyDrive/Python para inovação civica/conjunto_dados/consulta_cand_2020_RN.csv', '/content/drive/MyDrive/Python para inovação civica/conjunto_dados/consulta_cand_2020_PE.csv']

# %%
lista_df= []
for dados_estado in dados_todos_estados:
	df_estado = pd.read_csv(dados_estado, sep=';', encoding='Latin-1')
	lista_df.append(df_estado)

# %%
print(lista_df)
# Out:
# [       DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0      05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 1      05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 2      05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 3      05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 4      05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# ...           ...        ...          ...              ...                ...
# 10550  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 10551  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 10552  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 10553  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 10554  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
#
#        NR_TURNO  CD_ELEICAO                DS_ELEICAO  DT_ELEICAO  \
# 0             1         426  Eleições Municipais 2020  15/11/2020
# 1             1         426  Eleições Municipais 2020  15/11/2020
# 2             1         426  Eleições Municipais 2020  15/11/2020
# 3             1         426  Eleições Municipais 2020  15/11/2020
# 4             1         426  Eleições Municipais 2020  15/11/2020
# ...         ...         ...                       ...         ...
# 10550         1         426  Eleições Municipais 2020  15/11/2020
# 10551         1         426  Eleições Municipais 2020  15/11/2020
# 10552         1         426  Eleições Municipais 2020  15/11/2020
# 10553         1         426  Eleições Municipais 2020  15/11/2020
# 10554         1         426  Eleições Municipais 2020  15/11/2020
#
#       TP_ABRANGENCIA SG_UF  SG_UE                  NM_UE  CD_CARGO  \
# 0          MUNICIPAL    RN  17213        MESSIAS TARGINO        12
# 1          MUNICIPAL    RN  18791        TENENTE ANANIAS        13
# 2          MUNICIPAL    RN  17850                   PATU        13
# 3          MUNICIPAL    RN  16438           CANGUARETAMA        13
# 4          MUNICIPAL    RN  16390                  CAICÓ        13
# ...              ...   ...    ...                    ...       ...
# 10550      MUNICIPAL    RN  17418                MACAÍBA        13
# 10551      MUNICIPAL    RN  17639         NÍSIA FLORESTA        12
# 10552      MUNICIPAL    RN  17531              MONTANHAS        13
# 10553      MUNICIPAL    RN  18597  SENADOR ELÓI DE SOUZA        13
# 10554      MUNICIPAL    RN  17418                MACAÍBA        12
#
#             DS_CARGO  SQ_CANDIDATO  NR_CANDIDATO  \
# 0      VICE-PREFEITO  200000780811            22
# 1           VEREADOR  200001047834         10123
# 2           VEREADOR  200000949291         15111
# 3           VEREADOR  200001259271         22345
# 4           VEREADOR  200001242245         12666
# ...              ...           ...           ...
# 10550       VEREADOR  200001127844         40456
# 10551  VICE-PREFEITO  200000814425            17
# 10552       VEREADOR  200001049842         70111
# 10553       VEREADOR  200001062226         20888
# 10554  VICE-PREFEITO  200000669367            19
#
#                          NM_CANDIDATO       NM_URNA_CANDIDATO  \
# 0           ANDERSON MEDEIROS MARTINS                ANDERSON
# 1                        MANOEL FILHO                    NECO
# 2      EVERTON RENAN FERNANDES DANTAS                    EVIN
# 3             JOSIAS DOS SANTOS SILVA           PASTOR JOSIAS
# 4           WESCLEY BRITO DE MEDEIROS           IRMÃO WESCLEY
# ...                               ...                     ...
# 10550             LUIZ GONZAGA SOARES                LUIZINHO
# 10551           JAIR LIMA DE OLIVEIRA               DR. JAIR
# 10552          IVAN CORDEIRO DA COSTA  IVAN CORDEIRO DA COSTA
# 10553            MANOEL JORGE RIBEIRO            MANOEL JORGE
# 10554     VERA LÍGIA RIBEIRO FAGUNDES   PROFESSORA VERA LÍGIA
#
#       NM_SOCIAL_CANDIDATO  NR_CPF_CANDIDATO                          NM_EMAIL  \
# 0                  #NULO#        1179288440          ASSESORIA.PLMT@GMAIL.COM
# 1                  #NULO#       38186390430         NECOMANOELFILHO@GMAIL.COM
# 2                  #NULO#        1732839425               MDB15PATU@GMAIL.COM
# 3                  #NULO#        6771691403        PLCANGUARETAMA22@GMAIL.COM
# 4                  #NULO#         922136424  ROSILEIDEMEDEIROS21976@GMAIL.COM
# ...                   ...               ...                               ...
# 10550              #NULO#       20015437434          PSBMACAIBA40@HOTMAIL.COM
# 10551              #NULO#       20003434818        JAIROLIVEIRAADV@UOL.COM.BR
# 10552              #NULO#        2910302466     IVANCORDEIRODACOSTA@GMAIL.COM
# 10553              #NULO#       67141617434         PSC.ELOIDESOUZA@GMAIL.COM
# 10554              #NULO#       48103900478        VERALIGIA.R.F.68@GMAIL.COM
#
#        CD_SITUACAO_CANDIDATURA DS_SITUACAO_CANDIDATURA  \
# 0                           12                    APTO
# 1                           12                    APTO
# 2                           12                    APTO
# 3                           12                    APTO
# 4                           12                    APTO
# ...                        ...                     ...
# 10550                       12                    APTO
# 10551                       12                    APTO
# 10552                       12                    APTO
# 10553                       12                    APTO
# 10554                       12                    APTO
#
#        CD_DETALHE_SITUACAO_CAND DS_DETALHE_SITUACAO_CAND    TP_AGREMIACAO  \
# 0                             2                 DEFERIDO        COLIGAÇÃO
# 1                             2                 DEFERIDO  PARTIDO ISOLADO
# 2                             2                 DEFERIDO  PARTIDO ISOLADO
# 3                             2                 DEFERIDO  PARTIDO ISOLADO
# 4                             2                 DEFERIDO  PARTIDO ISOLADO
# ...                         ...                      ...              ...
# 10550                         2                 DEFERIDO  PARTIDO ISOLADO
# 10551                         2                 DEFERIDO  PARTIDO ISOLADO
# 10552                         2                 DEFERIDO  PARTIDO ISOLADO
# 10553                         2                 DEFERIDO  PARTIDO ISOLADO
# 10554                         2                 DEFERIDO  PARTIDO ISOLADO
#
#        NR_PARTIDO    SG_PARTIDO                        NM_PARTIDO  \
# 0              22            PL                   PARTIDO LIBERAL
# 1              10  REPUBLICANOS                      REPUBLICANOS
# 2              15           MDB  MOVIMENTO DEMOCRÁTICO BRASILEIRO
# 3              22            PL                   PARTIDO LIBERAL
# 4              12           PDT   PARTIDO DEMOCRÁTICO TRABALHISTA
# ...           ...           ...                               ...
# 10550          40           PSB     PARTIDO SOCIALISTA BRASILEIRO
# 10551          17           PSL            PARTIDO SOCIAL LIBERAL
# 10552          70        AVANTE                            AVANTE
# 10553          20           PSC            PARTIDO SOCIAL CRISTÃO
# 10554          19          PODE                           PODEMOS
#
#        SQ_COLIGACAO     NM_COLIGACAO DS_COMPOSICAO_COLIGACAO  \
# 0      200000075831   AVANÇA MESSIAS                 PT / PL
# 1      200000126636  PARTIDO ISOLADO            REPUBLICANOS
# 2      200000109887  PARTIDO ISOLADO                     MDB
# 3      200000161289  PARTIDO ISOLADO                      PL
# 4      200000153815  PARTIDO ISOLADO                     PDT
# ...             ...              ...                     ...
# 10550  200000136724  PARTIDO ISOLADO                     PSB
# 10551  200000083885  PARTIDO ISOLADO                     PSL
# 10552  200000126896  PARTIDO ISOLADO                  AVANTE
# 10553  200000128431  PARTIDO ISOLADO                     PSC
# 10554  200000059975  PARTIDO ISOLADO                    PODE
#
#        CD_NACIONALIDADE DS_NACIONALIDADE SG_UF_NASCIMENTO  \
# 0                     1  BRASILEIRA NATA               RN
# 1                     1  BRASILEIRA NATA               PB
# 2                     1  BRASILEIRA NATA               RN
# 3                     1  BRASILEIRA NATA               RJ
# 4                     1  BRASILEIRA NATA               RN
# ...                 ...              ...              ...
# 10550                 1  BRASILEIRA NATA               RN
# 10551                 1  BRASILEIRA NATA               RN
# 10552                 1  BRASILEIRA NATA               RN
# 10553                 1  BRASILEIRA NATA               RN
# 10554                 1  BRASILEIRA NATA               RN
#
#        CD_MUNICIPIO_NASCIMENTO  NM_MUNICIPIO_NASCIMENTO DT_NASCIMENTO  \
# 0                           -3                    NATAL    26/12/1983
# 1                           -3                   LASTRO    30/10/1963
# 2                           -3                     PATU    20/03/1993
# 3                           -3           RIO DE JANEIRO    12/01/1988
# 4                           -3                    CAICÓ    24/09/1981
# ...                        ...                      ...           ...
# 10550                       -3                  MACAÍBA    30/04/1957
# 10551                       -3                    NATAL    25/02/1973
# 10552                       -3                NOVA CRUZ    21/06/1978
# 10553                       -3    SENADOR ELÓI DE SOUZA    13/11/1967
# 10554                       -3  SÃO GONÇALO DO AMARANTE    24/03/1968
#
#        NR_IDADE_DATA_POSSE  NR_TITULO_ELEITORAL_CANDIDATO  CD_GENERO  \
# 0                       37                    20466441678          2
# 1                       57                     8822261635          2
# 2                       27                    29887831660          2
# 3                       32                    25199561600          2
# 4                       39                    18861311686          2
# ...                    ...                            ...        ...
# 10550                   63                     2709591678          2
# 10551                   47                   258183140141          2
# 10552                   42                    16697261600          2
# 10553                   53                    17373291686          2
# 10554                   52                     2647991600          4
#
#        DS_GENERO  CD_GRAU_INSTRUCAO              DS_GRAU_INSTRUCAO  \
# 0      MASCULINO                  8              SUPERIOR COMPLETO
# 1      MASCULINO                  4    ENSINO FUNDAMENTAL COMPLETO
# 2      MASCULINO                  6          ENSINO MÉDIO COMPLETO
# 3      MASCULINO                  6          ENSINO MÉDIO COMPLETO
# 4      MASCULINO                  6          ENSINO MÉDIO COMPLETO
# ...          ...                ...                            ...
# 10550  MASCULINO                  8              SUPERIOR COMPLETO
# 10551  MASCULINO                  8              SUPERIOR COMPLETO
# 10552  MASCULINO                  3  ENSINO FUNDAMENTAL INCOMPLETO
# 10553  MASCULINO                  4    ENSINO FUNDAMENTAL COMPLETO
# 10554   FEMININO                  8              SUPERIOR COMPLETO
#
#        CD_ESTADO_CIVIL DS_ESTADO_CIVIL  CD_COR_RACA DS_COR_RACA  CD_OCUPACAO  \
# 0                    1     SOLTEIRO(A)            3       PARDA          278
# 1                    1     SOLTEIRO(A)            3       PARDA          169
# 2                    1     SOLTEIRO(A)            3       PARDA          601
# 3                    3       CASADO(A)            2       PRETA          999
# 4                    1     SOLTEIRO(A)            1      BRANCA          712
# ...                ...             ...          ...         ...          ...
# 10550                3       CASADO(A)            1      BRANCA          131
# 10551                9   DIVORCIADO(A)            2       PRETA          131
# 10552                9   DIVORCIADO(A)            3       PARDA          601
# 10553                3       CASADO(A)            3       PARDA          601
# 10554                3       CASADO(A)            2       PRETA          265
#
#                                              DS_OCUPACAO  \
# 0                                               VEREADOR
# 1                                            COMERCIANTE
# 2                                             AGRICULTOR
# 3                                                 OUTROS
# 4      TRABALHADOR DE FABRICAÇÃO DE PRODUTOS TÊXTEIS ...
# ...                                                  ...
# 10550                                           ADVOGADO
# 10551                                           ADVOGADO
# 10552                                         AGRICULTOR
# 10553                                         AGRICULTOR
# 10554                    PROFESSOR DE ENSINO FUNDAMENTAL
#
#        VR_DESPESA_MAX_CAMPANHA  CD_SIT_TOT_TURNO DS_SIT_TOT_TURNO  \
# 0                        -1.00                 1           ELEITO
# 1                     15281.35                 5         SUPLENTE
# 2                     19863.34                 5         SUPLENTE
# 3                     24352.56                 5         SUPLENTE
# 4                     52350.27                 5         SUPLENTE
# ...                        ...               ...              ...
# 10550                 35829.59                 2    ELEITO POR QP
# 10551                    -1.00                 4       NÃO ELEITO
# 10552                 12307.75                 5         SUPLENTE
# 10553                 20355.58                 5         SUPLENTE
# 10554                    -1.00                 4       NÃO ELEITO
#
#       ST_REELEICAO ST_DECLARAR_BENS  NR_PROTOCOLO_CANDIDATURA  \
# 0                N                S                        -1
# 1                N                S                        -1
# 2                N                S                        -1
# 3                N                S                        -1
# 4                N                S                        -1
# ...            ...              ...                       ...
# 10550            N                S                        -1
# 10551            N                S                        -1
# 10552            N                S                        -1
# 10553            N                S                        -1
# 10554            N                S                        -1
#
#                NR_PROCESSO  CD_SITUACAO_CANDIDATO_PLEITO  \
# 0      6000968720206200037                             2
# 1      6002612520206200041                             2
# 2      6001834320206200037                             2
# 3      6005626220206200011                             2
# 4      6002608820206200025                             2
# ...                    ...                           ...
# 10550  6002596620206200005                             2
# 10551  6001133320206200067                             2
# 10552  6002967220206200012                             2
# 10553  6003116220206200005                             2
# 10554  6000717320206200005                             2
#
#       DS_SITUACAO_CANDIDATO_PLEITO  CD_SITUACAO_CANDIDATO_URNA  \
# 0                         DEFERIDO                           2
# 1                         DEFERIDO                           2
# 2                         DEFERIDO                           2
# 3                         DEFERIDO                           2
# 4                         DEFERIDO                           2
# ...                            ...                         ...
# 10550                     DEFERIDO                           2
# 10551                     DEFERIDO                           2
# 10552                     DEFERIDO                           2
# 10553                     DEFERIDO                           2
# 10554                     DEFERIDO                           2
#
#       DS_SITUACAO_CANDIDATO_URNA ST_CANDIDATO_INSERIDO_URNA
# 0                       DEFERIDO                        SIM
# 1                       DEFERIDO                        SIM
# 2                       DEFERIDO                        SIM
# 3                       DEFERIDO                        SIM
# 4                       DEFERIDO                        SIM
# ...                          ...                        ...
# 10550                   DEFERIDO                        SIM
# 10551                   DEFERIDO                        SIM
# 10552                   DEFERIDO                        SIM
# 10553                   DEFERIDO                        SIM
# 10554                   DEFERIDO                        SIM
#
# [10555 rows x 63 columns],        DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0      05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 1      05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 2      05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 3      05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 4      05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# ...           ...        ...          ...              ...                ...
# 21096  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 21097  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 21098  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 21099  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 21100  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
#
#        NR_TURNO  CD_ELEICAO                DS_ELEICAO  DT_ELEICAO  \
# 0             1         426  Eleições Municipais 2020  15/11/2020
# 1             1         426  Eleições Municipais 2020  15/11/2020
# 2             1         426  Eleições Municipais 2020  15/11/2020
# 3             1         426  Eleições Municipais 2020  15/11/2020
# 4             1         426  Eleições Municipais 2020  15/11/2020
# ...         ...         ...                       ...         ...
# 21096         1         426  Eleições Municipais 2020  15/11/2020
# 21097         1         426  Eleições Municipais 2020  15/11/2020
# 21098         1         426  Eleições Municipais 2020  15/11/2020
# 21099         1         426  Eleições Municipais 2020  15/11/2020
# 21100         1         426  Eleições Municipais 2020  15/11/2020
#
#       TP_ABRANGENCIA SG_UF  SG_UE          NM_UE  CD_CARGO  DS_CARGO  \
# 0          MUNICIPAL    PE  23817        CARUARU        13  VEREADOR
# 1          MUNICIPAL    PE  23094    ÁGUAS BELAS        13  VEREADOR
# 2          MUNICIPAL    PE  25313         RECIFE        13  VEREADOR
# 3          MUNICIPAL    PE  24970       OURICURI        13  VEREADOR
# 4          MUNICIPAL    PE  24996       PALMARES        13  VEREADOR
# ...              ...   ...    ...            ...       ...       ...
# 21096      MUNICIPAL    PE  24716  LAGOA DO OURO        13  VEREADOR
# 21097      MUNICIPAL    PE  23914        CONDADO        13  VEREADOR
# 21098      MUNICIPAL    PE  23710      CAMUTANGA        13  VEREADOR
# 21099      MUNICIPAL    PE  26310   ABREU E LIMA        13  VEREADOR
# 21100      MUNICIPAL    PE  24996       PALMARES        13  VEREADOR
#
#        SQ_CANDIDATO  NR_CANDIDATO                       NM_CANDIDATO  \
# 0      170001231149         17008    MARIA DE LOURDES ALVES DE SOUZA
# 1      170000800795         15515  JOSÉ MAREVALDO BARROS DE OLIVEIRA
# 2      170000836659         25033            JOSÉ AGNIS PERKLES RÊGO
# 3      170000648896         45777               DELVANI SILVA SOBRAL
# 4      170001129430         90090       MARILENE SHEILLA DE OLIVEIRA
# ...             ...           ...                                ...
# 21096  170000831074         11333    ADERBAL QUEIROZ MONTEIRO JUNIOR
# 21097  170000822680         14114          BERNADETE MONTEIRO FALCÃO
# 21098  170000758162         36555           GRAZIELE ROCHA DAMASCENO
# 21099  170000782931         23232       CLAUDENIER ALMEIDA DE ARAÚJO
# 21100  170001191022         45190            ELIAS SILVA DE OLIVEIRA
#
#                     NM_URNA_CANDIDATO NM_SOCIAL_CANDIDATO  NR_CPF_CANDIDATO  \
# 0             DONA LOURDES DA BONANÇA              #NULO#       12310328472
# 1                 MAREVALDO DA RUA 15              #NULO#       59971576449
# 2                          JOSÉ AGNIS              #NULO#       61079570730
# 3                     DELVANIA SOBRAL              #NULO#       68068123415
# 4            SHEILLA DO MEIO AMBIENTE              #NULO#        4522160445
# ...                               ...                 ...               ...
# 21096                 JÚNIOR MONTEIRO              #NULO#       36067776472
# 21097                BERNADETE FALCÃO              #NULO#       19696027400
# 21098                           GRAZI              #NULO#       10361236778
# 21099  NIER ARAÚJO MANDATO COLABORATI              #NULO#       84571489404
# 21100                    ELIAS DO GÁS              #NULO#        2699308412
#
#                           NM_EMAIL  CD_SITUACAO_CANDIDATURA  \
# 0       NG_CONSULTORIA@HOTMAIL.COM                       12
# 1      MDBABCAMPANHA2020@GMAIL.COM                       12
# 2      DIRETORIODEMREC25@GMAIL.COM                       12
# 3      DELVANIA_SOBRAL@HOTMAIL.COM                       12
# 4          MARC_GUEDES@HOTMAIL.COM                        3
# ...                            ...                      ...
# 21096     PAULINHOPT13@HOTMAIL.COM                       12
# 21097  BERNADETEFALCAO@HOTMAIL.COM                       12
# 21098       PTCCAMUTANGA@GMAIL.COM                       12
# 21099             NIER@NIER.COM.BR                       12
# 21100      MARC_GUEDES@HOTMAIL.COM                       12
#
#       DS_SITUACAO_CANDIDATURA  CD_DETALHE_SITUACAO_CAND  \
# 0                        APTO                         2
# 1                        APTO                         2
# 2                        APTO                         2
# 3                        APTO                         2
# 4                      INAPTO                         6
# ...                       ...                       ...
# 21096                    APTO                         2
# 21097                    APTO                         2
# 21098                    APTO                         2
# 21099                    APTO                         2
# 21100                    APTO                         2
#
#       DS_DETALHE_SITUACAO_CAND    TP_AGREMIACAO  NR_PARTIDO SG_PARTIDO  \
# 0                     DEFERIDO  PARTIDO ISOLADO          17        PSL
# 1                     DEFERIDO  PARTIDO ISOLADO          15        MDB
# 2                     DEFERIDO  PARTIDO ISOLADO          25        DEM
# 3                     DEFERIDO  PARTIDO ISOLADO          45       PSDB
# 4                     RENÚNCIA  PARTIDO ISOLADO          90       PROS
# ...                        ...              ...         ...        ...
# 21096                 DEFERIDO  PARTIDO ISOLADO          11         PP
# 21097                 DEFERIDO  PARTIDO ISOLADO          14        PTB
# 21098                 DEFERIDO  PARTIDO ISOLADO          36        PTC
# 21099                 DEFERIDO  PARTIDO ISOLADO          23  CIDADANIA
# 21100                 DEFERIDO  PARTIDO ISOLADO          45       PSDB
#
#                                     NM_PARTIDO  SQ_COLIGACAO     NM_COLIGACAO  \
# 0                       PARTIDO SOCIAL LIBERAL  170000152093  PARTIDO ISOLADO
# 1             MOVIMENTO DEMOCRÁTICO BRASILEIRO  170000078841  PARTIDO ISOLADO
# 2                                   DEMOCRATAS  170000088761  PARTIDO ISOLADO
# 3      PARTIDO DA SOCIAL DEMOCRACIA BRASILEIRA  170000057628  PARTIDO ISOLADO
# 4          PARTIDO REPUBLICANO DA ORDEM SOCIAL  170000136900  PARTIDO ISOLADO
# ...                                        ...           ...              ...
# 21096                            PROGRESSISTAS  170000087696  PARTIDO ISOLADO
# 21097           PARTIDO TRABALHISTA BRASILEIRO  170000086146  PARTIDO ISOLADO
# 21098              PARTIDO TRABALHISTA CRISTÃO  170000072791  PARTIDO ISOLADO
# 21099                                CIDADANIA  170000076102  PARTIDO ISOLADO
# 21100  PARTIDO DA SOCIAL DEMOCRACIA BRASILEIRA  170000146430  PARTIDO ISOLADO
#
#       DS_COMPOSICAO_COLIGACAO  CD_NACIONALIDADE           DS_NACIONALIDADE  \
# 0                         PSL                 1            BRASILEIRA NATA
# 1                         MDB                 1            BRASILEIRA NATA
# 2                         DEM                 1            BRASILEIRA NATA
# 3                        PSDB                 2  BRASILEIRA (NATURALIZADA)
# 4                        PROS                 1            BRASILEIRA NATA
# ...                       ...               ...                        ...
# 21096                      PP                 1            BRASILEIRA NATA
# 21097                     PTB                 1            BRASILEIRA NATA
# 21098                     PTC                 1            BRASILEIRA NATA
# 21099               CIDADANIA                 1            BRASILEIRA NATA
# 21100                    PSDB                 1            BRASILEIRA NATA
#
#       SG_UF_NASCIMENTO  CD_MUNICIPIO_NASCIMENTO NM_MUNICIPIO_NASCIMENTO  \
# 0                   PE                       -3                  RECIFE
# 1                   PE                       -3             ÁGUAS BELAS
# 2                   RJ                       -3          RIO DE JANEIRO
# 3                   PE                       -3                OURICURI
# 4                   AL                       -3                  MACEIÓ
# ...                ...                      ...                     ...
# 21096               PE                       -3               GARANHUNS
# 21097               PE                       -3                 ALIANÇA
# 21098               RJ                       -3          RIO DE JANEIRO
# 21099               PE                       -3            ABREU E LIMA
# 21100               PE                       -3                PALMARES
#
#       DT_NASCIMENTO  NR_IDADE_DATA_POSSE  NR_TITULO_ELEITORAL_CANDIDATO  \
# 0        09/10/1952                   68                     3341960884
# 1        28/09/1969                   51                    34158500825
# 2        27/05/1962                   58                    73197820337
# 3        10/03/1971                   49                    40086930833
# 4        26/07/1973                   47                    54096200809
# ...             ...                  ...                            ...
# 21096    02/01/1964                   56                    17923290884
# 21097    27/04/1958                   62                    30927730809
# 21098    06/04/1985                   35                   116398140302
# 21099    14/09/1973                   47                    40676680841
# 21100    21/06/1977                   43                    46061470892
#
#        CD_GENERO  DS_GENERO  CD_GRAU_INSTRUCAO              DS_GRAU_INSTRUCAO  \
# 0              4   FEMININO                  6          ENSINO MÉDIO COMPLETO
# 1              2  MASCULINO                  3  ENSINO FUNDAMENTAL INCOMPLETO
# 2              2  MASCULINO                  8              SUPERIOR COMPLETO
# 3              4   FEMININO                  8              SUPERIOR COMPLETO
# 4              4   FEMININO                  8              SUPERIOR COMPLETO
# ...          ...        ...                ...                            ...
# 21096          2  MASCULINO                  8              SUPERIOR COMPLETO
# 21097          4   FEMININO                  8              SUPERIOR COMPLETO
# 21098          4   FEMININO                  6          ENSINO MÉDIO COMPLETO
# 21099          2  MASCULINO                  8              SUPERIOR COMPLETO
# 21100          2  MASCULINO                  6          ENSINO MÉDIO COMPLETO
#
#        CD_ESTADO_CIVIL DS_ESTADO_CIVIL  CD_COR_RACA DS_COR_RACA  CD_OCUPACAO  \
# 0                    3       CASADO(A)            3       PARDA          999
# 1                    3       CASADO(A)            3       PARDA          999
# 2                    9   DIVORCIADO(A)            1      BRANCA          131
# 3                    1     SOLTEIRO(A)            3       PARDA          298
# 4                    1     SOLTEIRO(A)            3       PARDA          999
# ...                ...             ...          ...         ...          ...
# 21096                3       CASADO(A)            3       PARDA          131
# 21097                9   DIVORCIADO(A)            3       PARDA          999
# 21098                3       CASADO(A)            3       PARDA          513
# 21099                3       CASADO(A)            1      BRANCA          395
# 21100                1     SOLTEIRO(A)            3       PARDA          254
#
#                       DS_OCUPACAO  VR_DESPESA_MAX_CAMPANHA  CD_SIT_TOT_TURNO  \
# 0                          OUTROS                149376.80                 5
# 1                          OUTROS                 48405.01                 5
# 2                        ADVOGADO               1011149.65                 5
# 3      SERVIDOR PÚBLICO MUNICIPAL                 26120.37                 2
# 4                          OUTROS                 26666.50                -1
# ...                           ...                      ...               ...
# 21096                    ADVOGADO                 24284.49                 5
# 21097                      OUTROS                 17823.88                 5
# 21098       MANICURE E MAQUILADOR                 12307.75                 4
# 21099      BANCÁRIO E ECONOMIÁRIO                 28533.15                 4
# 21100                   VIGILANTE                 26666.50                 5
#
#       DS_SIT_TOT_TURNO ST_REELEICAO ST_DECLARAR_BENS  \
# 0             SUPLENTE            N                N
# 1             SUPLENTE            N                S
# 2             SUPLENTE            N                S
# 3        ELEITO POR QP            N                S
# 4               #NULO#            N                S
# ...                ...          ...              ...
# 21096         SUPLENTE            N                S
# 21097         SUPLENTE            N                S
# 21098       NÃO ELEITO            N                S
# 21099       NÃO ELEITO            N                S
# 21100         SUPLENTE            N                S
#
#        NR_PROTOCOLO_CANDIDATURA          NR_PROCESSO  \
# 0                            -1  6004724720206170105
# 1                            -1  6000665220206170064
# 2                            -1  6001433520206170008
# 3                            -1  6001353020206170082
# 4                            -1  6002360820206170037
# ...                         ...                  ...
# 21096                        -1  6001090420206170059
# 21097                        -1  6001523420206170125
# 21098                        -1  6001177720206170027
# 21099                        -1  6003031820206170119
# 21100                        -1  6002681320206170037
#
#        CD_SITUACAO_CANDIDATO_PLEITO DS_SITUACAO_CANDIDATO_PLEITO  \
# 0                                 2                     DEFERIDO
# 1                                 2                     DEFERIDO
# 2                                 2                     DEFERIDO
# 3                                 2                     DEFERIDO
# 4                                -1                       #NULO#
# ...                             ...                          ...
# 21096                             2                     DEFERIDO
# 21097                             2                     DEFERIDO
# 21098                             2                     DEFERIDO
# 21099                             2                     DEFERIDO
# 21100                             2                     DEFERIDO
#
#        CD_SITUACAO_CANDIDATO_URNA DS_SITUACAO_CANDIDATO_URNA  \
# 0                               2                   DEFERIDO
# 1                               2                   DEFERIDO
# 2                               2                   DEFERIDO
# 3                               2                   DEFERIDO
# 4                              -1                     #NULO#
# ...                           ...                        ...
# 21096                           2                   DEFERIDO
# 21097                           2                   DEFERIDO
# 21098                           2                   DEFERIDO
# 21099                           2                   DEFERIDO
# 21100                           2                   DEFERIDO
#
#       ST_CANDIDATO_INSERIDO_URNA
# 0                            SIM
# 1                            SIM
# 2                            SIM
# 3                            SIM
# 4                            NÃO
# ...                          ...
# 21096                        SIM
# 21097                        SIM
# 21098                        SIM
# 21099                        SIM
# 21100                        SIM
#
# [21101 rows x 63 columns]]

# %%
candidaturas_pe_rn = pd.concat(lista_df, axis=0, ignore_index=True)

# %%
candidaturas_pe_rn
# Out:
#        DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0      05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 1      05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 2      05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 3      05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 4      05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# ...           ...        ...          ...              ...                ...
# 31651  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 31652  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 31653  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 31654  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 31655  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
#
#        NR_TURNO  CD_ELEICAO                DS_ELEICAO  DT_ELEICAO  \
# 0             1         426  Eleições Municipais 2020  15/11/2020
# 1             1         426  Eleições Municipais 2020  15/11/2020
# 2             1         426  Eleições Municipais 2020  15/11/2020
# 3             1         426  Eleições Municipais 2020  15/11/2020
# 4             1         426  Eleições Municipais 2020  15/11/2020
# ...         ...         ...                       ...         ...
# 31651         1         426  Eleições Municipais 2020  15/11/2020
# 31652         1         426  Eleições Municipais 2020  15/11/2020
# 31653         1         426  Eleições Municipais 2020  15/11/2020
# 31654         1         426  Eleições Municipais 2020  15/11/2020
# 31655         1         426  Eleições Municipais 2020  15/11/2020
#
#       TP_ABRANGENCIA SG_UF  SG_UE            NM_UE  CD_CARGO       DS_CARGO  \
# 0          MUNICIPAL    RN  17213  MESSIAS TARGINO        12  VICE-PREFEITO
# 1          MUNICIPAL    RN  18791  TENENTE ANANIAS        13       VEREADOR
# 2          MUNICIPAL    RN  17850             PATU        13       VEREADOR
# 3          MUNICIPAL    RN  16438     CANGUARETAMA        13       VEREADOR
# 4          MUNICIPAL    RN  16390            CAICÓ        13       VEREADOR
# ...              ...   ...    ...              ...       ...            ...
# 31651      MUNICIPAL    PE  24716    LAGOA DO OURO        13       VEREADOR
# 31652      MUNICIPAL    PE  23914          CONDADO        13       VEREADOR
# 31653      MUNICIPAL    PE  23710        CAMUTANGA        13       VEREADOR
# 31654      MUNICIPAL    PE  26310     ABREU E LIMA        13       VEREADOR
# 31655      MUNICIPAL    PE  24996         PALMARES        13       VEREADOR
#
#        SQ_CANDIDATO  NR_CANDIDATO                     NM_CANDIDATO  \
# 0      200000780811            22        ANDERSON MEDEIROS MARTINS
# 1      200001047834         10123                     MANOEL FILHO
# 2      200000949291         15111   EVERTON RENAN FERNANDES DANTAS
# 3      200001259271         22345          JOSIAS DOS SANTOS SILVA
# 4      200001242245         12666        WESCLEY BRITO DE MEDEIROS
# ...             ...           ...                              ...
# 31651  170000831074         11333  ADERBAL QUEIROZ MONTEIRO JUNIOR
# 31652  170000822680         14114        BERNADETE MONTEIRO FALCÃO
# 31653  170000758162         36555         GRAZIELE ROCHA DAMASCENO
# 31654  170000782931         23232     CLAUDENIER ALMEIDA DE ARAÚJO
# 31655  170001191022         45190          ELIAS SILVA DE OLIVEIRA
#
#                     NM_URNA_CANDIDATO NM_SOCIAL_CANDIDATO  NR_CPF_CANDIDATO  \
# 0                            ANDERSON              #NULO#        1179288440
# 1                                NECO              #NULO#       38186390430
# 2                                EVIN              #NULO#        1732839425
# 3                       PASTOR JOSIAS              #NULO#        6771691403
# 4                       IRMÃO WESCLEY              #NULO#         922136424
# ...                               ...                 ...               ...
# 31651                 JÚNIOR MONTEIRO              #NULO#       36067776472
# 31652                BERNADETE FALCÃO              #NULO#       19696027400
# 31653                           GRAZI              #NULO#       10361236778
# 31654  NIER ARAÚJO MANDATO COLABORATI              #NULO#       84571489404
# 31655                    ELIAS DO GÁS              #NULO#        2699308412
#
#                                NM_EMAIL  CD_SITUACAO_CANDIDATURA  \
# 0              ASSESORIA.PLMT@GMAIL.COM                       12
# 1             NECOMANOELFILHO@GMAIL.COM                       12
# 2                   MDB15PATU@GMAIL.COM                       12
# 3            PLCANGUARETAMA22@GMAIL.COM                       12
# 4      ROSILEIDEMEDEIROS21976@GMAIL.COM                       12
# ...                                 ...                      ...
# 31651          PAULINHOPT13@HOTMAIL.COM                       12
# 31652       BERNADETEFALCAO@HOTMAIL.COM                       12
# 31653            PTCCAMUTANGA@GMAIL.COM                       12
# 31654                  NIER@NIER.COM.BR                       12
# 31655           MARC_GUEDES@HOTMAIL.COM                       12
#
#       DS_SITUACAO_CANDIDATURA  CD_DETALHE_SITUACAO_CAND  \
# 0                        APTO                         2
# 1                        APTO                         2
# 2                        APTO                         2
# 3                        APTO                         2
# 4                        APTO                         2
# ...                       ...                       ...
# 31651                    APTO                         2
# 31652                    APTO                         2
# 31653                    APTO                         2
# 31654                    APTO                         2
# 31655                    APTO                         2
#
#       DS_DETALHE_SITUACAO_CAND    TP_AGREMIACAO  NR_PARTIDO    SG_PARTIDO  \
# 0                     DEFERIDO        COLIGAÇÃO          22            PL
# 1                     DEFERIDO  PARTIDO ISOLADO          10  REPUBLICANOS
# 2                     DEFERIDO  PARTIDO ISOLADO          15           MDB
# 3                     DEFERIDO  PARTIDO ISOLADO          22            PL
# 4                     DEFERIDO  PARTIDO ISOLADO          12           PDT
# ...                        ...              ...         ...           ...
# 31651                 DEFERIDO  PARTIDO ISOLADO          11            PP
# 31652                 DEFERIDO  PARTIDO ISOLADO          14           PTB
# 31653                 DEFERIDO  PARTIDO ISOLADO          36           PTC
# 31654                 DEFERIDO  PARTIDO ISOLADO          23     CIDADANIA
# 31655                 DEFERIDO  PARTIDO ISOLADO          45          PSDB
#
#                                     NM_PARTIDO  SQ_COLIGACAO     NM_COLIGACAO  \
# 0                              PARTIDO LIBERAL  200000075831   AVANÇA MESSIAS
# 1                                 REPUBLICANOS  200000126636  PARTIDO ISOLADO
# 2             MOVIMENTO DEMOCRÁTICO BRASILEIRO  200000109887  PARTIDO ISOLADO
# 3                              PARTIDO LIBERAL  200000161289  PARTIDO ISOLADO
# 4              PARTIDO DEMOCRÁTICO TRABALHISTA  200000153815  PARTIDO ISOLADO
# ...                                        ...           ...              ...
# 31651                            PROGRESSISTAS  170000087696  PARTIDO ISOLADO
# 31652           PARTIDO TRABALHISTA BRASILEIRO  170000086146  PARTIDO ISOLADO
# 31653              PARTIDO TRABALHISTA CRISTÃO  170000072791  PARTIDO ISOLADO
# 31654                                CIDADANIA  170000076102  PARTIDO ISOLADO
# 31655  PARTIDO DA SOCIAL DEMOCRACIA BRASILEIRA  170000146430  PARTIDO ISOLADO
#
#       DS_COMPOSICAO_COLIGACAO  CD_NACIONALIDADE DS_NACIONALIDADE  \
# 0                     PT / PL                 1  BRASILEIRA NATA
# 1                REPUBLICANOS                 1  BRASILEIRA NATA
# 2                         MDB                 1  BRASILEIRA NATA
# 3                          PL                 1  BRASILEIRA NATA
# 4                         PDT                 1  BRASILEIRA NATA
# ...                       ...               ...              ...
# 31651                      PP                 1  BRASILEIRA NATA
# 31652                     PTB                 1  BRASILEIRA NATA
# 31653                     PTC                 1  BRASILEIRA NATA
# 31654               CIDADANIA                 1  BRASILEIRA NATA
# 31655                    PSDB                 1  BRASILEIRA NATA
#
#       SG_UF_NASCIMENTO  CD_MUNICIPIO_NASCIMENTO NM_MUNICIPIO_NASCIMENTO  \
# 0                   RN                       -3                   NATAL
# 1                   PB                       -3                  LASTRO
# 2                   RN                       -3                    PATU
# 3                   RJ                       -3          RIO DE JANEIRO
# 4                   RN                       -3                   CAICÓ
# ...                ...                      ...                     ...
# 31651               PE                       -3               GARANHUNS
# 31652               PE                       -3                 ALIANÇA
# 31653               RJ                       -3          RIO DE JANEIRO
# 31654               PE                       -3            ABREU E LIMA
# 31655               PE                       -3                PALMARES
#
#       DT_NASCIMENTO  NR_IDADE_DATA_POSSE  NR_TITULO_ELEITORAL_CANDIDATO  \
# 0        26/12/1983                   37                    20466441678
# 1        30/10/1963                   57                     8822261635
# 2        20/03/1993                   27                    29887831660
# 3        12/01/1988                   32                    25199561600
# 4        24/09/1981                   39                    18861311686
# ...             ...                  ...                            ...
# 31651    02/01/1964                   56                    17923290884
# 31652    27/04/1958                   62                    30927730809
# 31653    06/04/1985                   35                   116398140302
# 31654    14/09/1973                   47                    40676680841
# 31655    21/06/1977                   43                    46061470892
#
#        CD_GENERO  DS_GENERO  CD_GRAU_INSTRUCAO            DS_GRAU_INSTRUCAO  \
# 0              2  MASCULINO                  8            SUPERIOR COMPLETO
# 1              2  MASCULINO                  4  ENSINO FUNDAMENTAL COMPLETO
# 2              2  MASCULINO                  6        ENSINO MÉDIO COMPLETO
# 3              2  MASCULINO                  6        ENSINO MÉDIO COMPLETO
# 4              2  MASCULINO                  6        ENSINO MÉDIO COMPLETO
# ...          ...        ...                ...                          ...
# 31651          2  MASCULINO                  8            SUPERIOR COMPLETO
# 31652          4   FEMININO                  8            SUPERIOR COMPLETO
# 31653          4   FEMININO                  6        ENSINO MÉDIO COMPLETO
# 31654          2  MASCULINO                  8            SUPERIOR COMPLETO
# 31655          2  MASCULINO                  6        ENSINO MÉDIO COMPLETO
#
#        CD_ESTADO_CIVIL DS_ESTADO_CIVIL  CD_COR_RACA DS_COR_RACA  CD_OCUPACAO  \
# 0                    1     SOLTEIRO(A)            3       PARDA          278
# 1                    1     SOLTEIRO(A)            3       PARDA          169
# 2                    1     SOLTEIRO(A)            3       PARDA          601
# 3                    3       CASADO(A)            2       PRETA          999
# 4                    1     SOLTEIRO(A)            1      BRANCA          712
# ...                ...             ...          ...         ...          ...
# 31651                3       CASADO(A)            3       PARDA          131
# 31652                9   DIVORCIADO(A)            3       PARDA          999
# 31653                3       CASADO(A)            3       PARDA          513
# 31654                3       CASADO(A)            1      BRANCA          395
# 31655                1     SOLTEIRO(A)            3       PARDA          254
#
#                                              DS_OCUPACAO  \
# 0                                               VEREADOR
# 1                                            COMERCIANTE
# 2                                             AGRICULTOR
# 3                                                 OUTROS
# 4      TRABALHADOR DE FABRICAÇÃO DE PRODUTOS TÊXTEIS ...
# ...                                                  ...
# 31651                                           ADVOGADO
# 31652                                             OUTROS
# 31653                              MANICURE E MAQUILADOR
# 31654                             BANCÁRIO E ECONOMIÁRIO
# 31655                                          VIGILANTE
#
#        VR_DESPESA_MAX_CAMPANHA  CD_SIT_TOT_TURNO DS_SIT_TOT_TURNO  \
# 0                        -1.00                 1           ELEITO
# 1                     15281.35                 5         SUPLENTE
# 2                     19863.34                 5         SUPLENTE
# 3                     24352.56                 5         SUPLENTE
# 4                     52350.27                 5         SUPLENTE
# ...                        ...               ...              ...
# 31651                 24284.49                 5         SUPLENTE
# 31652                 17823.88                 5         SUPLENTE
# 31653                 12307.75                 4       NÃO ELEITO
# 31654                 28533.15                 4       NÃO ELEITO
# 31655                 26666.50                 5         SUPLENTE
#
#       ST_REELEICAO ST_DECLARAR_BENS  NR_PROTOCOLO_CANDIDATURA  \
# 0                N                S                        -1
# 1                N                S                        -1
# 2                N                S                        -1
# 3                N                S                        -1
# 4                N                S                        -1
# ...            ...              ...                       ...
# 31651            N                S                        -1
# 31652            N                S                        -1
# 31653            N                S                        -1
# 31654            N                S                        -1
# 31655            N                S                        -1
#
#                NR_PROCESSO  CD_SITUACAO_CANDIDATO_PLEITO  \
# 0      6000968720206200037                             2
# 1      6002612520206200041                             2
# 2      6001834320206200037                             2
# 3      6005626220206200011                             2
# 4      6002608820206200025                             2
# ...                    ...                           ...
# 31651  6001090420206170059                             2
# 31652  6001523420206170125                             2
# 31653  6001177720206170027                             2
# 31654  6003031820206170119                             2
# 31655  6002681320206170037                             2
#
#       DS_SITUACAO_CANDIDATO_PLEITO  CD_SITUACAO_CANDIDATO_URNA  \
# 0                         DEFERIDO                           2
# 1                         DEFERIDO                           2
# 2                         DEFERIDO                           2
# 3                         DEFERIDO                           2
# 4                         DEFERIDO                           2
# ...                            ...                         ...
# 31651                     DEFERIDO                           2
# 31652                     DEFERIDO                           2
# 31653                     DEFERIDO                           2
# 31654                     DEFERIDO                           2
# 31655                     DEFERIDO                           2
#
#       DS_SITUACAO_CANDIDATO_URNA ST_CANDIDATO_INSERIDO_URNA
# 0                       DEFERIDO                        SIM
# 1                       DEFERIDO                        SIM
# 2                       DEFERIDO                        SIM
# 3                       DEFERIDO                        SIM
# 4                       DEFERIDO                        SIM
# ...                          ...                        ...
# 31651                   DEFERIDO                        SIM
# 31652                   DEFERIDO                        SIM
# 31653                   DEFERIDO                        SIM
# 31654                   DEFERIDO                        SIM
# 31655                   DEFERIDO                        SIM
#
# [31656 rows x 63 columns]

# %%
candidaturas_pe_rn.shape
# Out:
# (31656, 63)

# %%
candidaturas_pe_rn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31656 entries, 0 to 31655
# Data columns (total 63 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   DT_GERACAO                     31656 non-null  object
#  1   HH_GERACAO                     31656 non-null  object
#  2   ANO_ELEICAO                    31656 non-null  int64
#  3   CD_TIPO_ELEICAO                31656 non-null  int64
#  4   NM_TIPO_ELEICAO                31656 non-null  object
#  5   NR_TURNO                       31656 non-null  int64
#  6   CD_ELEICAO                     31656 non-null  int64
#  7   DS_ELEICAO                     31656 non-null  object
#  8   DT_ELEICAO                     31656 non-null  object
#  9   TP_ABRANGENCIA                 31656 non-null  object
#  10  SG_UF                          31656 non-null  object
#  11  SG_UE                          31656 non-null  int64
#  12  NM_UE                          31656 non-null  object
#  13  CD_CARGO                       31656 non-null  int64
#  14  DS_CARGO                       31656 non-null  object
#  15  SQ_CANDIDATO                   31656 non-null  int64
#  16  NR_CANDIDATO                   31656 non-null  int64
#  17  NM_CANDIDATO                   31656 non-null  object
#  18  NM_URNA_CANDIDATO              31656 non-null  object
#  19  NM_SOCIAL_CANDIDATO            31656 non-null  object
#  20  NR_CPF_CANDIDATO               31656 non-null  int64
#  21  NM_EMAIL                       31656 non-null  object
#  22  CD_SITUACAO_CANDIDATURA        31656 non-null  int64
#  23  DS_SITUACAO_CANDIDATURA        31656 non-null  object
#  24  CD_DETALHE_SITUACAO_CAND       31656 non-null  int64
#  25  DS_DETALHE_SITUACAO_CAND       31656 non-null  object
#  26  TP_AGREMIACAO                  31656 non-null  object
#  27  NR_PARTIDO                     31656 non-null  int64
#  28  SG_PARTIDO                     31656 non-null  object
#  29  NM_PARTIDO                     31656 non-null  object
#  30  SQ_COLIGACAO                   31656 non-null  int64
#  31  NM_COLIGACAO                   31656 non-null  object
#  32  DS_COMPOSICAO_COLIGACAO        31656 non-null  object
#  33  CD_NACIONALIDADE               31656 non-null  int64
#  34  DS_NACIONALIDADE               31656 non-null  object
#  35  SG_UF_NASCIMENTO               31656 non-null  object
#  36  CD_MUNICIPIO_NASCIMENTO        31656 non-null  int64
#  37  NM_MUNICIPIO_NASCIMENTO        31656 non-null  object
#  38  DT_NASCIMENTO                  31656 non-null  object
#  39  NR_IDADE_DATA_POSSE            31656 non-null  int64
#  40  NR_TITULO_ELEITORAL_CANDIDATO  31656 non-null  int64
#  41  CD_GENERO                      31656 non-null  int64
#  42  DS_GENERO                      31656 non-null  object
#  43  CD_GRAU_INSTRUCAO              31656 non-null  int64
#  44  DS_GRAU_INSTRUCAO              31656 non-null  object
#  45  CD_ESTADO_CIVIL                31656 non-null  int64
#  46  DS_ESTADO_CIVIL                31656 non-null  object
#  47  CD_COR_RACA                    31656 non-null  int64
#  48  DS_COR_RACA                    31656 non-null  object
#  49  CD_OCUPACAO                    31656 non-null  int64
#  50  DS_OCUPACAO                    31656 non-null  object
#  51  VR_DESPESA_MAX_CAMPANHA        31656 non-null  float64
#  52  CD_SIT_TOT_TURNO               31656 non-null  int64
#  53  DS_SIT_TOT_TURNO               31656 non-null  object
#  54  ST_REELEICAO                   31656 non-null  object
#  55  ST_DECLARAR_BENS               31656 non-null  object
#  56  NR_PROTOCOLO_CANDIDATURA       31656 non-null  int64
#  57  NR_PROCESSO                    31656 non-null  int64
#  58  CD_SITUACAO_CANDIDATO_PLEITO   31656 non-null  int64
#  59  DS_SITUACAO_CANDIDATO_PLEITO   31656 non-null  object
#  60  CD_SITUACAO_CANDIDATO_URNA     31656 non-null  int64
#  61  DS_SITUACAO_CANDIDATO_URNA     31656 non-null  object
#  62  ST_CANDIDATO_INSERIDO_URNA     31656 non-null  object
# dtypes: float64(1), int64(27), object(35)
# memory usage: 15.2+ MB

# %%
candidaturas_pe_rn.isnull().sum()
# Out:
# DT_GERACAO                      0
# HH_GERACAO                      0
# ANO_ELEICAO                     0
# CD_TIPO_ELEICAO                 0
# NM_TIPO_ELEICAO                 0
#                                ..
# CD_SITUACAO_CANDIDATO_PLEITO    0
# DS_SITUACAO_CANDIDATO_PLEITO    0
# CD_SITUACAO_CANDIDATO_URNA      0
# DS_SITUACAO_CANDIDATO_URNA      0
# ST_CANDIDATO_INSERIDO_URNA      0
# Length: 63, dtype: int64
