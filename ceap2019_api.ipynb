# %% [markdown]
# <a href="https://colab.research.google.com/github/Rosangelafl/exercicios_python_inovacao_civica/blob/main/ceap2019_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install plotly==5.2.1

# %%
import pandas as pd

# %%
pd.options.plotting.backend = 'plotly'

# %%
df = pd.read_csv('/content/drive/MyDrive/Python para inovação civica/semana_3/Ano-2019.csv', sep=';',
                 parse_dates=['datEmissao'])
df.head()
# Out:
#   txNomeParlamentar  ...                                       urlDocumento
# 0        LID.GOV-CD  ...  http://camara.leg.br/cota-parlamentar/nota-fis...
# 1        LID.GOV-CD  ...  http://camara.leg.br/cota-parlamentar/nota-fis...
# 2        LID.GOV-CD  ...  http://camara.leg.br/cota-parlamentar/nota-fis...
# 3        LID.GOV-CD  ...  http://camara.leg.br/cota-parlamentar/nota-fis...
# 4        LID.GOV-CD  ...  http://camara.leg.br/cota-parlamentar/nota-fis...
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288937 entries, 0 to 288936
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   txNomeParlamentar          288937 non-null  object
#  1   cpf                        287934 non-null  float64
#  2   ideCadastro                288032 non-null  float64
#  3   nuCarteiraParlamentar      288032 non-null  float64
#  4   nuLegislatura              288937 non-null  int64
#  5   sgUF                       288032 non-null  object
#  6   sgPartido                  288032 non-null  object
#  7   codLegislatura             288937 non-null  int64
#  8   numSubCota                 288937 non-null  int64
#  9   txtDescricao               288937 non-null  object
#  10  numEspecificacaoSubCota    288937 non-null  int64
#  11  txtDescricaoEspecificacao  64765 non-null   object
#  12  txtFornecedor              288922 non-null  object
# ...

# %%
df.columns.values
# Out:
# array(['txNomeParlamentar', 'cpf', 'ideCadastro', 'nuCarteiraParlamentar',
#        'nuLegislatura', 'sgUF', 'sgPartido', 'codLegislatura',
#        'numSubCota', 'txtDescricao', 'numEspecificacaoSubCota',
#        'txtDescricaoEspecificacao', 'txtFornecedor', 'txtCNPJCPF',
#        'txtNumero', 'indTipoDocumento', 'datEmissao', 'vlrDocumento',
#        'vlrGlosa', 'vlrLiquido', 'numMes', 'numAno', 'numParcela',
#        'txtPassageiro', 'txtTrecho', 'numLote', 'numRessarcimento',
#        'vlrRestituicao', 'nuDeputadoId', 'ideDocumento', 'urlDocumento'],
#       dtype=object)

# %%
 df.txNomeParlamentar = df.txNomeParlamentar.str.title()

# %%
df['cpf'] = df['cpf'].apply(str)

# %%
df['ideCadastro'] = df['ideCadastro'].apply(str)

# %%
df['nuCarteiraParlamentar'] = df['nuCarteiraParlamentar'].apply(str)

# %%
df['ideDocumento'] = df['ideDocumento'].apply(str)

# %%
df['nuDeputadoId'] = df['nuDeputadoId'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288937 entries, 0 to 288936
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   txNomeParlamentar          288937 non-null  object
#  1   cpf                        288937 non-null  object
#  2   ideCadastro                288937 non-null  object
#  3   nuCarteiraParlamentar      288937 non-null  object
#  4   nuLegislatura              288937 non-null  int64
#  5   sgUF                       288032 non-null  object
#  6   sgPartido                  288032 non-null  object
#  7   codLegislatura             288937 non-null  int64
#  8   numSubCota                 288937 non-null  int64
#  9   txtDescricao               288937 non-null  object
#  10  numEspecificacaoSubCota    288937 non-null  int64
#  11  txtDescricaoEspecificacao  64765 non-null   object
#  12  txtFornecedor              288922 non-null  object
# ...

# %%
df.sample(5)
# Out:
#        txNomeParlamentar  ...                                       urlDocumento
# 204051    Aroldo Martins  ...  http://camara.leg.br/cota-parlamentar/nota-fis...
# 101312      Bruna Furlan  ...                                                NaN
# 56243     Marcelo Moraes  ...                                                NaN
# 132482         Paulo Azi  ...                                                NaN
# 148556     Luciano Ducci  ...  https://www.camara.leg.br/cota-parlamentar/doc...
#
# [5 rows x 31 columns]

# %%
df['txNomeParlamentar'].value_counts()
# Out:
# Diego Garcia        1735
# Zeca Dirceu         1631
# Maria Do Rosário    1540
# Glauber Braga       1489
# Jorge Solla         1425
#                     ...
# Otavio Leite           2
# Sarney Filho           1
# Mandetta               1
# Geraldo Resende        1
# Luciana Santos         1
# Name: txNomeParlamentar, Length: 820, dtype: int64

# %%
df.fillna(value="Não se aplica").head(2)
# Out:
#   txNomeParlamentar  ...                                       urlDocumento
# 0        Lid.Gov-Cd  ...  http://camara.leg.br/cota-parlamentar/nota-fis...
# 1        Lid.Gov-Cd  ...  http://camara.leg.br/cota-parlamentar/nota-fis...
#
# [2 rows x 31 columns]

# %%
df[df.sgPartido.isna()]
# Out:
#     txNomeParlamentar  ...                                       urlDocumento
# 0          Lid.Gov-Cd  ...  http://camara.leg.br/cota-parlamentar/nota-fis...
# 1          Lid.Gov-Cd  ...  http://camara.leg.br/cota-parlamentar/nota-fis...
# 2          Lid.Gov-Cd  ...  http://camara.leg.br/cota-parlamentar/nota-fis...
# 3          Lid.Gov-Cd  ...  http://camara.leg.br/cota-parlamentar/nota-fis...
# 4          Lid.Gov-Cd  ...  http://camara.leg.br/cota-parlamentar/nota-fis...
# ..                ...  ...                                                ...
# 900            Lidmin  ...  http://camara.leg.br/cota-parlamentar/nota-fis...
# 901            Lidmin  ...  https://www.camara.leg.br/cota-parlamentar/doc...
# 902            Lidmin  ...  https://www.camara.leg.br/cota-parlamentar/doc...
# 903            Lidmin  ...  https://www.camara.leg.br/cota-parlamentar/doc...
# 904            Lidmin  ...  http://camara.leg.br/cota-parlamentar/nota-fis...
#
# [905 rows x 31 columns]

# %%
df[df['ideDocumento'].isnull()]
# Out:
# Empty DataFrame
# Columns: [txNomeParlamentar, cpf, ideCadastro, nuCarteiraParlamentar, nuLegislatura, sgUF, sgPartido, codLegislatura, numSubCota, txtDescricao, numEspecificacaoSubCota, txtDescricaoEspecificacao, txtFornecedor, txtCNPJCPF, txtNumero, indTipoDocumento, datEmissao, vlrDocumento, vlrGlosa, vlrLiquido, numMes, numAno, numParcela, txtPassageiro, txtTrecho, numLote, numRessarcimento, vlrRestituicao, nuDeputadoId, ideDocumento, urlDocumento]
# Index: []

# %%
# vamos trocar qualquer caracter que não seja um dígito número por '', essa operação remove os dígitos
df["txtCNPJCPF"] = df["txtCNPJCPF"].str.replace(r'\D', '', regex=True)

# %%
f = df.sgPartido.isna()
df['sgPartido'] = df[f].txNomeParlamentar.replace('Lid.Gov-', '')

# %%
converters = {0: 'nota_fiscal', 1: 'recibo', 2: 'despesa_exterior'}
df.indTipoDocumento.replace(converters, inplace=True)

# %%
#entendo a distribuição dos valores númericos
#https://felipegalvao.com.br/pt/blog/descriptive-statistics-with-python/


df['vlrDocumento'].max()
# Out:
# 172000.0

# %%
round(df['vlrDocumento'].mean(), 2)
# Out:
# 739.14

# %%
round(df['vlrDocumento'].median(), 2)
# Out:
# 195.04

# %%
df['vlrDocumento'].describe()
# Out:
# count    288937.000000
# mean        739.141305
# std        2130.524866
# min       -6605.570000
# 25%          50.000000
# 50%         195.040000
# 75%         724.890000
# max      172000.000000
# Name: vlrDocumento, dtype: float64

# %%
round(df['vlrDocumento'].quantile(q=0.25), 2)
# Out:
# 50.0

# %%
round(df['vlrDocumento'].quantile(q=0.75), 2)
# Out:
# 724.89

# %%
round(df['vlrDocumento'].var(),2)
# Out:
# 4539136.21

# %%
round(df['vlrDocumento'].std(),2)
# Out:
# 2130.52

# %%
#Desvio absoluto
round(df['vlrDocumento'].mad(),2)
# Out:
# 907.79

# %%
round(df['vlrDocumento'].mode(),2)
# Out:
# 0    100.0
# dtype: float64

# %%
print(df.corr())
# Out:
#                          nuLegislatura  ...  vlrRestituicao
# nuLegislatura                 1.000000  ...       -0.076195
# codLegislatura                1.000000  ...       -0.076195
# numSubCota                    0.016704  ...       -0.114585
# numEspecificacaoSubCota       0.002755  ...        0.147738
# vlrDocumento                 -0.031070  ...        0.931711
# vlrGlosa                     -0.012539  ...        0.618772
# vlrLiquido                   -0.031880  ...             NaN
# numMes                        0.396970  ...        0.085163
# numAno                             NaN  ...             NaN
# numParcela                   -0.014298  ...             NaN
# numLote                       0.031077  ...        0.106735
# numRessarcimento                   NaN  ...             NaN
# vlrRestituicao               -0.076195  ...        1.000000
#
# [13 rows x 13 columns]

# %%
df['txtDescricao'].value_counts()
# Out:
# PASSAGEM AÉREA - RPA                                         81512
# COMBUSTÍVEIS E LUBRIFICANTES.                                64765
# SERVIÇO DE TÁXI, PEDÁGIO E ESTACIONAMENTO                    31557
# MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE PARLAMENTAR    22014
# TELEFONIA                                                    21880
# FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                   17743
# SERVIÇOS POSTAIS                                             14961
# DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                         10946
# LOCAÇÃO OU FRETAMENTO DE VEÍCULOS AUTOMOTORES                 6279
# HOSPEDAGEM ,EXCETO DO PARLAMENTAR NO DISTRITO FEDERAL.        5579
# PASSAGEM AÉREA - SIGEPA                                       3655
# PASSAGEM AÉREA - REEMBOLSO                                    3148
# CONSULTORIAS, PESQUISAS E TRABALHOS TÉCNICOS.                 2397
# PASSAGENS TERRESTRES, MARÍTIMAS OU FLUVIAIS                   1136
# ...

# %%
df['txtDescricao'].value_counts().head(10).sort_values(ascending=True).plot(kind='barh')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Os deputados que mais viajaram?
df['txtPassageiro'].value_counts()
# Out:
# Soraya Santos         472
# Eduardo da Fonte      418
# Wolney Queiroz        396
# Claudio Cajado        365
# Rubens Bueno          364
#                      ...
# EMERSON RODRIGUES       1
# JESUITO CRUZ            1
# SAMUEL SILVA            1
# LEONARDO DOLIVEIRA      1
# FRANKLIN ROCHA          1
# Name: txtPassageiro, Length: 4891, dtype: int64

# %%
df['txtPassageiro'].value_counts().head(10).sort_values(ascending=True).plot(kind='barh', title='Os dez deputados que mais viajaram')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df[df['vlrLiquido'] > 100000]
# Out:
#                         txNomeParlamentar  ...                                       urlDocumento
# 88620                       Weliton Prado  ...  https://www.camara.leg.br/cota-parlamentar/doc...
# 109705  Professora Dorinha Seabra Rezende  ...  https://www.camara.leg.br/cota-parlamentar/doc...
# 280459                     Raimundo Costa  ...  https://www.camara.leg.br/cota-parlamentar/doc...
#
# [3 rows x 31 columns]

# %%
rb = df[df['txNomeParlamentar'] == 'Ricardo Barros']

# %%
rb.head()
# Out:
#       txNomeParlamentar  ...                                       urlDocumento
# 13428    Ricardo Barros  ...  https://www.camara.leg.br/cota-parlamentar/doc...
# 13429    Ricardo Barros  ...  http://camara.leg.br/cota-parlamentar/nota-fis...
# 13430    Ricardo Barros  ...  http://camara.leg.br/cota-parlamentar/nota-fis...
# 13431    Ricardo Barros  ...  http://camara.leg.br/cota-parlamentar/nota-fis...
# 13432    Ricardo Barros  ...  https://www.camara.leg.br/cota-parlamentar/doc...
#
# [5 rows x 31 columns]

# %%
rb['txtDescricao'].value_counts().sort_values(ascending=True).plot(kind='barh')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
round(rb['vlrDocumento'].sum(),2)
# Out:
# 476809.8

# %%
round(rb['vlrDocumento'].max(),2)
# Out:
# 21360.0

# %%
rb[rb['vlrDocumento'] == 21360.0]
# Out:
#       txNomeParlamentar  ...                                       urlDocumento
# 13481    Ricardo Barros  ...  https://www.camara.leg.br/cota-parlamentar/doc...
#
# [1 rows x 31 columns]

# %%
 df.groupby('txNomeParlamentar')['vlrDocumento'].sum().reset_index()
# Out:
#      txNomeParlamentar  vlrDocumento
# 0    Abel Mesquita Jr.      45955.79
# 1            Abou Anni     248952.15
# 2       Abílio Santana     429009.88
# 3       Acácio Favacho     476578.53
# 4       Adail Carneiro      42249.14
# ..                 ...           ...
# 815           Zé Silva     425288.11
# 816           Zé Vitor     377963.82
# 817         Átila Lins     482056.23
# 818         Átila Lira     450439.18
# 819     Áurea Carolina     383258.51
#
# [820 rows x 2 columns]

# %%
df.groupby('txNomeParlamentar')['txtDescricao'].value_counts()
# Out:
# txNomeParlamentar  txtDescricao
# Abel Mesquita Jr.  PASSAGEM AÉREA - RPA                                        5
#                    TELEFONIA                                                   5
#                    COMBUSTÍVEIS E LUBRIFICANTES.                               1
#                    DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                        1
#                    LOCAÇÃO OU FRETAMENTO DE VEÍCULOS AUTOMOTORES               1
#                                                                               ..
# Áurea Carolina     DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                        7
#                    PASSAGENS TERRESTRES, MARÍTIMAS OU FLUVIAIS                 7
#                    CONSULTORIAS, PESQUISAS E TRABALHOS TÉCNICOS.               5
#                    SERVIÇO DE SEGURANÇA PRESTADO POR EMPRESA ESPECIALIZADA.    5
#                    FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                  1
# Name: txtDescricao, Length: 7237, dtype: int64

# %%
df.groupby('txNomeParlamentar').get_group('Áurea Carolina')
# Out:
#        txNomeParlamentar  ...                                       urlDocumento
# 249720    Áurea Carolina  ...  https://www.camara.leg.br/cota-parlamentar/doc...
# 249721    Áurea Carolina  ...  https://www.camara.leg.br/cota-parlamentar/doc...
# 249722    Áurea Carolina  ...  https://www.camara.leg.br/cota-parlamentar/doc...
# 249723    Áurea Carolina  ...  https://www.camara.leg.br/cota-parlamentar/doc...
# 249724    Áurea Carolina  ...  https://www.camara.leg.br/cota-parlamentar/doc...
# ...                  ...  ...                                                ...
# 250375    Áurea Carolina  ...                                                NaN
# 250376    Áurea Carolina  ...                                                NaN
# 250377    Áurea Carolina  ...                                                NaN
# 250378    Áurea Carolina  ...                                                NaN
# 250379    Áurea Carolina  ...                                                NaN
#
# ...

# %%
df.sort_values(by='vlrDocumento', ascending=False).groupby('txNomeParlamentar').first()
# Out:
#                              cpf  ...                                       urlDocumento
# txNomeParlamentar                 ...
# Abel Mesquita Jr.  18286585291.0  ...  https://www.camara.leg.br/cota-parlamentar/doc...
# Abou Anni           8496582841.0  ...  https://www.camara.leg.br/cota-parlamentar/doc...
# Abílio Santana     36607606504.0  ...  https://www.camara.leg.br/cota-parlamentar/doc...
# Acácio Favacho     74287028287.0  ...  http://camara.leg.br/cota-parlamentar/nota-fis...
# Adail Carneiro     21048215334.0  ...  https://www.camara.leg.br/cota-parlamentar/doc...
# ...                          ...  ...                                                ...
# Zé Silva           43422780653.0  ...  http://camara.leg.br/cota-parlamentar/nota-fis...
# Zé Vitor            7284044608.0  ...  https://www.camara.leg.br/cota-parlamentar/doc...
# Átila Lins           694584215.0  ...  https://www.camara.leg.br/cota-parlamentar/doc...
# ...
